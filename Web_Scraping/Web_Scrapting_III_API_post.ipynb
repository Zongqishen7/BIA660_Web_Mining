# %% [markdown]
# # <center>Web Scraping by API </center>

# %% [markdown]
# ## 1. Scrape data through APIs
# - Online content providers usually provide APIs for you to access data. Two types of APIs:
#    * Python packages: e.g. tweepy package from Twitter
#    * REST APIs: e.g. OMDB APIs (http://www.omdbapi.com), or TMDB (https://developers.themoviedb.org/3/getting-started)
# - You need to read documentation of APIs to figure out how to access data

# %% [markdown]
# ## 2. Scrape data by REST APIs (e.g. OMDB API)
# - A REST API is a web service that uses `HTTP` requests to `GET`, `PUT`, `POST` and `DELETE` data
# - Example:
#     - https://groceries.asda.com/api/items/search<font color="blue"><b>?</b></font><font color='green'><b>keyword</b></font>=<font color='red'><b>yogurt<b></font><front color='purple'><b>&</b></font><font color='green'><b>r</b></font>=<font color='red'><b>json<b></font>, where
#         - `?`: separate API endpoint  `https://groceries.asda.com/api/items/search` from parameters
#         - `keyword=yogurt`: search `yogurt` on parameter `keyword`
#         - `&`: combine multiple search criteria
#         - `r=json`: result is in json format
#     - You can directly paste the above API to your browser
#     - Or issue API calls using requests
# - You need to read API documentation to understand how to specify parameters

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import requests
import json
import pandas as pd

# %%
import requests
import json

keyword = 'yogurt'


url="https://groceries.asda.com/api/items/search?keyword=" + keyword + "&r=json"

print(url)

# invoke the API 
r = requests.get(url)

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    # json. dumps() function converts a Python object into a json string
    result = r.json()
    print (json.dumps(result, indent=4))
# Out:
# https://groceries.asda.com/api/items/search?keyword=yogurt&r=json
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "queryRelaxed": false,
#     "isHookLogicInsert": "false",
#     "totalResult": "447",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_5f8046bf0931946b86fb4387^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362225",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228362",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245221",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#             "pricePerUOM": "",
#             "searchTuningScore": "9486254.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "O",
#             "totalReviewCount": "43",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Vanilla Yogurt & Granola",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4186",
#             "name": "Activia Low Fat Vanilla Yogurt & Granola",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "7188797.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362239",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228322",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "143g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245092",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.375",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#             "pricePerUOM": "",
#             "searchTuningScore": "6455880.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203595",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "43",
#             "asdaSuggest": "",
#             "itemName": "Strawberry, Red Berry and Peach Flavour Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555677",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062467",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6977",
#             "name": "Frubes Strawberry, Red Berry and Peach Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555677",
#             "pricePerUOM": "",
#             "searchTuningScore": "5867831.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362227",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228335",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245207",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228335",
#             "pricePerUOM": "",
#             "searchTuningScore": "5107219.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638102",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Vanilla Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446045",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453674",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Munch Bunch Double Up Strawberry & Vanilla Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446045",
#             "pricePerUOM": "",
#             "searchTuningScore": "5064930.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006854",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Strawberry No Added Sugar Gut Health Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068276",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506289",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6579",
#             "name": "Activia Strawberry No Added Sugar Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068276",
#             "pricePerUOM": "",
#             "searchTuningScore": "4666910.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346362",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "18",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Toffee Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808315",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243579",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3889",
#             "name": "Muller Light Fat Free Toffee Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808315",
#             "pricePerUOM": "",
#             "searchTuningScore": "4484969.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2206832",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Squashums Strawberry Yogurt Drinks",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "48537352",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "6x90g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "8410100200736",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2667",
#             "name": "Munch Bunch Squashums Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=48537352",
#             "pricePerUOM": "",
#             "searchTuningScore": "4087592.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006850",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "64",
#             "asdaSuggest": "",
#             "itemName": "Rhubarb Gut Health Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068820",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506166",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6562",
#             "name": "Activia Rhubarb Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068820",
#             "pricePerUOM": "",
#             "searchTuningScore": "3743093.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3922315",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "71",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000786632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058338925",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6761",
#             "name": "Oykos Strawberry Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000786632",
#             "pricePerUOM": "",
#             "searchTuningScore": "3709469.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006848",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Peach No Added Sugar Gut Health Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067858",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506203",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5263",
#             "name": "Activia Peach No Added Sugar Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067858",
#             "pricePerUOM": "",
#             "searchTuningScore": "3382439.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2105",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "3184937.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786444",
#             "promoDetailFull": "2 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Apricot & Strawberry Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458398",
#             "promoId": "ls91538",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Petits Filous",
#             "promoType": "No Promo",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051577",
#             "promoDetail": "2 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4222",
#             "name": "Petits Filous Apricot & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458398",
#             "pricePerUOM": "",
#             "searchTuningScore": "3078784.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362229",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228313",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245146",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0909",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228313",
#             "pricePerUOM": "",
#             "searchTuningScore": "3021964.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5375861",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "57",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Greek Style Raspberry Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002325352",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Light & Free",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360501772",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5439",
#             "name": "Light & Free Fat Free Greek Style Raspberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002325352",
#             "pricePerUOM": "",
#             "searchTuningScore": "2571464.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203593",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "35",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Flavour Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062481",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5143",
#             "name": "Frubes Strawberry Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555632",
#             "pricePerUOM": "",
#             "searchTuningScore": "2525565.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286439451",
#             "shelfName": "Natural, Plain & Organic",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5035968",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Natural Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001817523",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.25",
#             "brandName": "Arla Skyr",
#             "promoType": "Rollback",
#             "weight": "450g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4016241030573",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5778",
#             "name": "Arla Skyr Natural Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "1215559958453",
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001817523",
#             "pricePerUOM": "",
#             "searchTuningScore": "2298570.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1044649",
#             "promoDetailFull": "2 for \u00a34.00",
#             "availability": "O",
#             "totalReviewCount": "160",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt Drinks",
#             "price": "\u00a32.75",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "976012",
#             "promoId": "ls91554",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "5410146407024",
#             "promoDetail": "2 for \u00a34.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6375",
#             "name": "Actimel Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=976012",
#             "pricePerUOM": "",
#             "searchTuningScore": "2089041.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "29",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.3448",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "2083189.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786442",
#             "promoDetailFull": "2 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "86",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Strawberry Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458097",
#             "promoId": "ls91538",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Petits Filous",
#             "promoType": "No Promo",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051584",
#             "promoDetail": "2 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3372",
#             "name": "Petits Filous Raspberry & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458097",
#             "pricePerUOM": "",
#             "searchTuningScore": "2073369.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5207976",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "57",
#             "asdaSuggest": "",
#             "itemName": "Salted Caramel Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002079621",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360501437",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6316",
#             "name": "Oykos Salted Caramel Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002079621",
#             "pricePerUOM": "",
#             "searchTuningScore": "2062051.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4776662",
#             "promoDetailFull": "2 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "89",
#             "asdaSuggest": "",
#             "itemName": "Yollies Strawberry Yogurt Lollies",
#             "price": "\u00a31.75",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001451015",
#             "promoId": "ls91687",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Strings & Things",
#             "promoType": "No Promo",
#             "weight": "4x25g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108084",
#             "promoDetail": "2 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.3146",
#             "name": "Strings & Things Yollies Strawberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001451015",
#             "pricePerUOM": "",
#             "searchTuningScore": "1814130.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3675692",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Raspberry Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000463345",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453926",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2222",
#             "name": "Munch Bunch Double Up Strawberry & Raspberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000463345",
#             "pricePerUOM": "",
#             "searchTuningScore": "1646327.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1230300",
#             "promoDetailFull": "2 for \u00a34.00",
#             "availability": "A",
#             "totalReviewCount": "195",
#             "asdaSuggest": "",
#             "itemName": "Multifruit Yogurt Drinks",
#             "price": "\u00a32.75",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "1429710",
#             "promoId": "ls91554",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "5016769993724",
#             "promoDetail": "2 for \u00a34.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6359",
#             "name": "Actimel Multifruit Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1429710",
#             "pricePerUOM": "",
#             "searchTuningScore": "1553932.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
# ...
#             "pricePerUOM": "",
#             "searchTuningScore": "128631.03",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639170517",
#             "shelfName": "Chocolate & Caramel Desserts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "3::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6510885",
#             "promoDetailFull": "3 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "7",
#             "asdaSuggest": "",
#             "itemName": "Dairy Milk Chunks Chocolate Dessert",
#             "price": "\u00a30.75",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "1000160202778",
#             "promoId": "ls91552",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Cadbury",
#             "promoType": "No Promo",
#             "weight": "85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "3",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "4025500252120",
#             "promoDetail": "3 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4286",
#             "name": "Cadbury Dairy Milk Chunks Chocolate Dessert",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600048"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000160202778",
#             "pricePerUOM": "",
#             "searchTuningScore": "128366.555",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4714089",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "20",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Apple Low Fat Desserts",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001390131",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Muller Rice",
#             "promoType": "Rollback",
#             "weight": "6x180g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183790",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5",
#             "name": "Muller Rice Raspberry & Apple Low Fat Desserts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001390131",
#             "pricePerUOM": "",
#             "searchTuningScore": "125970.414",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639198219",
#             "shelfName": "Mousse",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5177942",
#             "promoDetailFull": "",
#             "availability": "O",
#             "totalReviewCount": "10",
#             "asdaSuggest": "",
#             "itemName": "White Chocolate Mousse",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910002040524",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Milkybar",
#             "promoType": "Rollback",
#             "weight": "4x55g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290114360",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Milkybar White Chocolate Mousse",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002040524",
#             "pricePerUOM": "",
#             "searchTuningScore": "122342.41",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639299553",
#             "shelfName": "M\u00fcller Rice",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4765106",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Strawberry & Original Low Fat Desserts",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Desserts",
#             "id": "910001437655",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Muller Rice",
#             "promoType": "Rollback",
#             "weight": "6x180g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "4025500183851",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5333",
#             "name": "Muller Rice Strawberry & Original Low Fat Desserts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001437655",
#             "pricePerUOM": "",
#             "searchTuningScore": "63568.402",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "358"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Fresh Food & Bakery",
#             "displayName": "Fresh Food & Bakery",
#             "itemCount": "23"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Drinks",
#             "displayName": "Drinks",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Health & Beauty",
#             "displayName": "Health & Beauty",
#             "itemCount": "3"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Frozen Food",
#             "displayName": "Frozen Food",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoCeleryincludingceleriac",
#             "displayName": "NoCeleryincludingceleriac",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoFish",
#             "displayName": "NoFish",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoLupin",
#             "displayName": "NoLupin",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoMustard",
#             "displayName": "NoMustard",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoShellfish",
#             "displayName": "NoShellfish",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoSesame",
#             "displayName": "NoSesame",
#             "itemCount": "409"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Vegetarian",
#             "displayName": "Vegetarian",
#             "itemCount": "364"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoSoya",
#             "displayName": "NoSoya",
#             "itemCount": "351"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowSalt",
#             "displayName": "LowSalt",
#             "itemCount": "348"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoEgg",
#             "displayName": "NoEgg",
#             "itemCount": "341"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoGluten",
#             "displayName": "NoGluten",
#             "itemCount": "313"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoPeanuts",
#             "displayName": "NoPeanuts",
#             "itemCount": "294"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoNuts",
#             "displayName": "NoNuts",
#             "itemCount": "291"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowFat",
#             "displayName": "LowFat",
#             "itemCount": "198"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowSaturatedFat",
#             "displayName": "LowSaturatedFat",
#             "itemCount": "116"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoLactose",
#             "displayName": "NoLactose",
#             "itemCount": "73"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowSugar",
#             "displayName": "LowSugar",
#             "itemCount": "71"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoMilk",
#             "displayName": "NoMilk",
#             "itemCount": "48"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:SourceofFibre",
#             "displayName": "SourceofFibre",
#             "itemCount": "37"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Vegan",
#             "displayName": "Vegan",
#             "itemCount": "33"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:HighFibre",
#             "displayName": "HighFibre",
#             "itemCount": "7"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Kosher",
#             "displayName": "Kosher",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Ofaday",
#             "displayName": "Ofaday",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "81"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Light",
#             "displayName": "Muller Light",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Corner",
#             "displayName": "Muller Corner",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yazoo",
#             "displayName": "Yazoo",
#             "itemCount": "10"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 50,
#     "statusCode": "0"
# }

# %%
# Exercise 2.2.  Another way to pass parameters

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# in case authentication is needed, use
# r = requests.get('https://api.github.com/user', \
# auth=('user', 'pass'))

# if the API call returns a successful response
if r.status_code==200:
    
    # This API call returns a json object
    # r.json() gives the json object
    print (json.dumps(r.json(), indent=4))
# Out:
# {
#     "statusMessage": "The API Item Search was executed successfully",
#     "errors": [],
#     "keyword": "yogurt",
#     "storeId": "4565",
#     "autoCorrectedTerm": "",
#     "didYouMeanTerm": "",
#     "queryRelaxed": false,
#     "isHookLogicInsert": "false",
#     "totalResult": "447",
#     "currentPage": "1",
#     "resultsStartIndex": "1",
#     "resultsEndIndex": "60",
#     "maxPages": "8",
#     "qusApplied": false,
#     "productBoostingDetails": "0^rule_5f8046bf0931946b86fb4387^^^Default",
#     "monetizedItems": [],
#     "items": [
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362225",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228362",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245221",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.8",
#             "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#             "pricePerUOM": "",
#             "searchTuningScore": "9486254.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6202233",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "O",
#             "totalReviewCount": "43",
#             "asdaSuggest": "",
#             "itemName": "Low Fat Vanilla Yogurt & Granola",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078311452",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "",
#             "brandName": "Activia",
#             "promoType": "No Promo",
#             "weight": "165g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "5060360502960",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4186",
#             "name": "Activia Low Fat Vanilla Yogurt & Granola",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#             "pricePerUOM": "",
#             "searchTuningScore": "7188797.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362239",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "8",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228322",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "143g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245092",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.375",
#             "name": "Muller Corner Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228322",
#             "pricePerUOM": "",
#             "searchTuningScore": "6455880.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203595",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "43",
#             "asdaSuggest": "",
#             "itemName": "Strawberry, Red Berry and Peach Flavour Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555677",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062467",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6977",
#             "name": "Frubes Strawberry, Red Berry and Peach Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555677",
#             "pricePerUOM": "",
#             "searchTuningScore": "5867831.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362227",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Banana Yogurt with Chocolate Flakes",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228335",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245207",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0",
#             "name": "Muller Corner Banana Yogurt with Chocolate Flakes",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228335",
#             "pricePerUOM": "",
#             "searchTuningScore": "5107219.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3638102",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Vanilla Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000446045",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453674",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "5.0",
#             "name": "Munch Bunch Double Up Strawberry & Vanilla Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000446045",
#             "pricePerUOM": "",
#             "searchTuningScore": "5064930.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006854",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Strawberry No Added Sugar Gut Health Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068276",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506289",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6579",
#             "name": "Activia Strawberry No Added Sugar Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068276",
#             "pricePerUOM": "",
#             "searchTuningScore": "4666910.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "2206832",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "15",
#             "asdaSuggest": "",
#             "itemName": "Squashums Strawberry Yogurt Drinks",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "48537352",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "6x90g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "8410100200736",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2667",
#             "name": "Munch Bunch Squashums Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=48537352",
#             "pricePerUOM": "",
#             "searchTuningScore": "4087592.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006850",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "64",
#             "asdaSuggest": "",
#             "itemName": "Rhubarb Gut Health Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290068820",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506166",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6562",
#             "name": "Activia Rhubarb Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290068820",
#             "pricePerUOM": "",
#             "searchTuningScore": "3743093.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3922315",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "71",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000786632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058338925",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6761",
#             "name": "Oykos Strawberry Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000786632",
#             "pricePerUOM": "",
#             "searchTuningScore": "3709469.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286423096",
#             "shelfName": "Activia Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "7006848",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "38",
#             "asdaSuggest": "",
#             "itemName": "Peach No Added Sugar Gut Health Yogurt",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000290067858",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Activia",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360506203",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5263",
#             "name": "Activia Peach No Added Sugar Gut Health Yogurt",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000290067858",
#             "pricePerUOM": "",
#             "searchTuningScore": "3382439.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346360",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "19",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Banana and Custard Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808339",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243555",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2105",
#             "name": "Muller Light Fat Free Banana and Custard Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808339",
#             "pricePerUOM": "",
#             "searchTuningScore": "3184937.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786444",
#             "promoDetailFull": "2 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "45",
#             "asdaSuggest": "",
#             "itemName": "Apricot & Strawberry Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458398",
#             "promoId": "ls91538",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Petits Filous",
#             "promoType": "No Promo",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051577",
#             "promoDetail": "2 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.4222",
#             "name": "Petits Filous Apricot & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458398",
#             "pricePerUOM": "",
#             "searchTuningScore": "3078784.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215286383583",
#             "shelfName": "Corners",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6362229",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "11",
#             "asdaSuggest": "",
#             "itemName": "Toffee Yogurt with Chocolate Hoops",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000120228313",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Corner",
#             "promoType": "No Promo",
#             "weight": "130g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500245146",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.0909",
#             "name": "Muller Corner Toffee Yogurt with Chocolate Hoops",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228313",
#             "pricePerUOM": "",
#             "searchTuningScore": "3021964.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346354",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "12",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Strawberry Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808369",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243357",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5833",
#             "name": "Muller Light Fat Free Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808369",
#             "pricePerUOM": "",
#             "searchTuningScore": "2920521.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5375861",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "57",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Greek Style Raspberry Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002325352",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Light & Free",
#             "promoType": "Rollback",
#             "weight": "4x115g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360501772",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5439",
#             "name": "Light & Free Fat Free Greek Style Raspberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002325352",
#             "pricePerUOM": "",
#             "searchTuningScore": "2571464.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6203593",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "35",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Flavour Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000078555632",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Frubes",
#             "promoType": "Rollback",
#             "weight": "9x37g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3329770062481",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.5143",
#             "name": "Frubes Strawberry Flavour Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "45100001",
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078555632",
#             "pricePerUOM": "",
#             "searchTuningScore": "2525565.5",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1044649",
#             "promoDetailFull": "2 for \u00a34.00",
#             "availability": "O",
#             "totalReviewCount": "160",
#             "asdaSuggest": "",
#             "itemName": "Strawberry Yogurt Drinks",
#             "price": "\u00a32.75",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "976012",
#             "promoId": "ls91554",
#             "isFavourite": "false",
#             "hasAlternates": "true",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "5410146407024",
#             "promoDetail": "2 for \u00a34.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6375",
#             "name": "Actimel Strawberry Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=976012",
#             "pricePerUOM": "",
#             "searchTuningScore": "2089041.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "8::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6346374",
#             "promoDetailFull": "8 for \u00a34",
#             "availability": "A",
#             "totalReviewCount": "29",
#             "asdaSuggest": "",
#             "itemName": "Fat Free Limited Edition Yogurt",
#             "price": "\u00a30.55",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000116808405",
#             "promoId": "ls91605",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Muller Light",
#             "promoType": "No Promo",
#             "weight": "160g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "8",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "4025500243715",
#             "promoDetail": "8 for \u00a34",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "2.3448",
#             "name": "Muller Light Fat Free Limited Edition Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600049"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000116808405",
#             "pricePerUOM": "",
#             "searchTuningScore": "2083189.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4786442",
#             "promoDetailFull": "2 for \u00a32.00",
#             "availability": "A",
#             "totalReviewCount": "86",
#             "asdaSuggest": "",
#             "itemName": "Raspberry & Strawberry Yogurt",
#             "price": "\u00a31.50",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001458097",
#             "promoId": "ls91538",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Petits Filous",
#             "promoType": "No Promo",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "3329770051584",
#             "promoDetail": "2 for \u00a32.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3372",
#             "name": "Petits Filous Raspberry & Strawberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600050"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001458097",
#             "pricePerUOM": "",
#             "searchTuningScore": "2073369.1",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5207976",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "57",
#             "asdaSuggest": "",
#             "itemName": "Salted Caramel Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910002079621",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060360501437",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6316",
#             "name": "Oykos Salted Caramel Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910002079621",
#             "pricePerUOM": "",
#             "searchTuningScore": "2062051.8",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4776662",
#             "promoDetailFull": "2 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "89",
#             "asdaSuggest": "",
#             "itemName": "Yollies Strawberry Yogurt Lollies",
#             "price": "\u00a31.75",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001451015",
#             "promoId": "ls91687",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Strings & Things",
#             "promoType": "No Promo",
#             "weight": "4x25g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108084",
#             "promoDetail": "2 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.3146",
#             "name": "Strings & Things Yollies Strawberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001451015",
#             "pricePerUOM": "",
#             "searchTuningScore": "1814130.0",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3675692",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "9",
#             "asdaSuggest": "",
#             "itemName": "Double Up Strawberry & Raspberry Yogurts",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000463345",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.50",
#             "brandName": "Munch Bunch",
#             "promoType": "Rollback",
#             "weight": "4x85g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "3023290453926",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.2222",
#             "name": "Munch Bunch Double Up Strawberry & Raspberry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "59600051"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000463345",
#             "pricePerUOM": "",
#             "searchTuningScore": "1646327.4",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639169975",
#             "shelfName": "Probiotic, Health & Kefir Drinks",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a34::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "1230300",
#             "promoDetailFull": "2 for \u00a34.00",
#             "availability": "A",
#             "totalReviewCount": "195",
#             "asdaSuggest": "",
#             "itemName": "Multifruit Yogurt Drinks",
#             "price": "\u00a32.75",
#             "imageURL": "",
#             "aisleName": "Healthy Yogurt Drinks",
#             "id": "1429710",
#             "promoId": "ls91554",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Actimel",
#             "promoType": "No Promo",
#             "weight": "8x100g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a34",
#             "productAttribute": "",
#             "scene7AssetId": "5016769993724",
#             "promoDetail": "2 for \u00a34.00",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.6359",
#             "name": "Actimel Multifruit Yogurt Drinks",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1429710",
#             "pricePerUOM": "",
#             "searchTuningScore": "1553932.2",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215639963408",
#             "shelfName": "Greek Style",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3922311",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "78",
#             "asdaSuggest": "",
#             "itemName": "Peach Greek Style Yogurts",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910000786516",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a32.00",
#             "brandName": "Oykos",
#             "promoType": "Rollback",
#             "weight": "4x110g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5060058338888",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.7308",
#             "name": "Oykos Peach Greek Style Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000786516",
#             "pricePerUOM": "",
#             "searchTuningScore": "1340173.9",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215685641283",
#             "shelfName": "Dairy Free Yogurts & Desserts",
#             "deptId": "1215685641183",
#             "deptName": "Dairy Free Food & Drink",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3599470",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "64",
# ...
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001437655",
#             "pricePerUOM": "",
#             "searchTuningScore": "63568.402",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000976085",
#             "shelfName": "Kids Yogurts",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "2::for::\u00a32::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "4776664",
#             "promoDetailFull": "2 for \u00a32",
#             "availability": "A",
#             "totalReviewCount": "13",
#             "asdaSuggest": "",
#             "itemName": "Yollies Raspberry Yogurt Lollies",
#             "price": "\u00a31.75",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001450265",
#             "promoId": "ls91687",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Strings & Things",
#             "promoType": "No Promo",
#             "weight": "4x25g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "2",
#             "promoValue": "\u00a32",
#             "productAttribute": "",
#             "scene7AssetId": "5010252108107",
#             "promoDetail": "2 for \u00a32",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.5385",
#             "name": "Strings & Things Yollies Raspberry Yogurt Lollies",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001450265",
#             "pricePerUOM": "",
#             "searchTuningScore": "4639.7188",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "4::for::\u00a33::false",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "5033894",
#             "promoDetailFull": "4 for \u00a33",
#             "availability": "A",
#             "totalReviewCount": "14",
#             "asdaSuggest": "",
#             "itemName": "Raspberry Yogurt",
#             "price": "\u00a31.00",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "910001813465",
#             "promoId": "ls90172",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "",
#             "brandName": "Arla Protein",
#             "promoType": "No Promo",
#             "weight": "200g",
#             "promoOfferTypeCode": "15",
#             "promoQty": "4",
#             "promoValue": "\u00a33",
#             "productAttribute": "",
#             "scene7AssetId": "6413300018035",
#             "promoDetail": "4 for \u00a33",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.8571",
#             "name": "Arla Protein Raspberry Yogurt",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "49100001"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910001813465",
#             "pricePerUOM": "",
#             "searchTuningScore": "3851.296",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "910000977060",
#             "shelfName": "Fat Free & Low Fat",
#             "deptId": "1215341888021",
#             "deptName": "Yogurts & Desserts",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "6587681",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "59",
#             "asdaSuggest": "",
#             "itemName": "Strawberry & Cherry Yogurts",
#             "price": "\u00a32.25",
#             "imageURL": "",
#             "aisleName": "Yogurts & Fromage Frais",
#             "id": "1000184511950",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a33.00",
#             "brandName": "Benecol",
#             "promoType": "Rollback",
#             "weight": "4x120",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5055940101497",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "4.3729",
#             "name": "Benecol Strawberry & Cherry Yogurts",
#             "avgWeight": "",
#             "iconDetails": {},
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000184511950",
#             "pricePerUOM": "",
#             "searchTuningScore": "3478.3816",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         },
#         {
#             "shelfId": "1215685641283",
#             "shelfName": "Dairy Free Yogurts & Desserts",
#             "deptId": "1215685641183",
#             "deptName": "Dairy Free Food & Drink",
#             "isBundle": "false",
#             "meatStickerDetails": "",
#             "extraLargeImageURL": "",
#             "bundledItemCount": "0",
#             "scene7Host": "https://ui.assets-asda.com:443/dm/",
#             "cin": "3291777",
#             "promoDetailFull": "",
#             "availability": "A",
#             "totalReviewCount": "55",
#             "asdaSuggest": "",
#             "itemName": "Plain Soya Yogurt Alternative",
#             "price": "\u00a31.25",
#             "imageURL": "",
#             "aisleName": "Dairy Free Yogurts & Desserts",
#             "id": "910000297653",
#             "promoId": "",
#             "isFavourite": "false",
#             "hasAlternates": "false",
#             "wasPrice": "\u00a31.60",
#             "brandName": "Alpro",
#             "promoType": "Rollback",
#             "weight": "500g",
#             "promoOfferTypeCode": "",
#             "promoQty": "",
#             "promoValue": "",
#             "productAttribute": "",
#             "scene7AssetId": "5411188099154",
#             "promoDetail": "",
#             "bundleDiscount": "0.00",
#             "avgStarRating": "3.9273",
#             "name": "Alpro Plain Soya Yogurt Alternative",
#             "avgWeight": "",
#             "iconDetails": {
#                 "promotionalIcons": [
#                     "1215665168862",
#                     "1215665172999",
#                     "49100001",
#                     "59600014"
#                 ],
#                 "informationalIcons": []
#             },
#             "maxQty": "10.0",
#             "pricePerWt": "Each",
#             "productURL": "https://groceries.asda.com:443/api/items/view?itemid=910000297653",
#             "pricePerUOM": "",
#             "searchTuningScore": "3215.6096",
#             "onSale": false,
#             "salePrice": "",
#             "positionChngByMargin": 0
#         }
#     ],
#     "facets": [
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Chilled Food",
#             "displayName": "Chilled Food",
#             "itemCount": "358"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Fresh Food & Bakery",
#             "displayName": "Fresh Food & Bakery",
#             "itemCount": "23"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Free From...",
#             "displayName": "Free From...",
#             "itemCount": "17"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Food Cupboard",
#             "displayName": "Food Cupboard",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Baby, Toddler & Kids",
#             "displayName": "Baby, Toddler & Kids",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Drinks",
#             "displayName": "Drinks",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:World & Local Food",
#             "displayName": "World & Local Food",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Health & Beauty",
#             "displayName": "Health & Beauty",
#             "itemCount": "3"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Frozen Food",
#             "displayName": "Frozen Food",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Category",
#             "value": "super_dept_name:Pet Food & Accessories",
#             "displayName": "Pet Food & Accessories",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoCeleryincludingceleriac",
#             "displayName": "NoCeleryincludingceleriac",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoFish",
#             "displayName": "NoFish",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoLupin",
#             "displayName": "NoLupin",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoMustard",
#             "displayName": "NoMustard",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoShellfish",
#             "displayName": "NoShellfish",
#             "itemCount": "422"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoSesame",
#             "displayName": "NoSesame",
#             "itemCount": "409"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Vegetarian",
#             "displayName": "Vegetarian",
#             "itemCount": "364"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoSoya",
#             "displayName": "NoSoya",
#             "itemCount": "351"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowSalt",
#             "displayName": "LowSalt",
#             "itemCount": "348"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoEgg",
#             "displayName": "NoEgg",
#             "itemCount": "341"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoGluten",
#             "displayName": "NoGluten",
#             "itemCount": "313"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoPeanuts",
#             "displayName": "NoPeanuts",
#             "itemCount": "294"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoNuts",
#             "displayName": "NoNuts",
#             "itemCount": "291"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowFat",
#             "displayName": "LowFat",
#             "itemCount": "198"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowSaturatedFat",
#             "displayName": "LowSaturatedFat",
#             "itemCount": "116"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoLactose",
#             "displayName": "NoLactose",
#             "itemCount": "73"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:LowSugar",
#             "displayName": "LowSugar",
#             "itemCount": "71"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:NoMilk",
#             "displayName": "NoMilk",
#             "itemCount": "48"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:SourceofFibre",
#             "displayName": "SourceofFibre",
#             "itemCount": "37"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Vegan",
#             "displayName": "Vegan",
#             "itemCount": "33"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:HighFibre",
#             "displayName": "HighFibre",
#             "itemCount": "7"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Kosher",
#             "displayName": "Kosher",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Dietary & Lifestyle",
#             "value": "nutritional_info:Ofaday",
#             "displayName": "Ofaday",
#             "itemCount": "1"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA",
#             "displayName": "ASDA",
#             "itemCount": "81"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Activia",
#             "displayName": "Activia",
#             "itemCount": "15"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Cadbury",
#             "displayName": "Cadbury",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Light",
#             "displayName": "Muller Light",
#             "itemCount": "14"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:ASDA Extra Special",
#             "displayName": "ASDA Extra Special",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Actimel",
#             "displayName": "Actimel",
#             "itemCount": "13"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Muller Corner",
#             "displayName": "Muller Corner",
#             "itemCount": "11"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:GU",
#             "displayName": "GU",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Lindahls",
#             "displayName": "Lindahls",
#             "itemCount": "10"
#         },
#         {
#             "facetName": "Brand",
#             "value": "product_brand:Yazoo",
#             "displayName": "Yazoo",
#             "itemCount": "10"
#         }
#     ],
#     "mediaContent": "",
#     "useKeywordAsIcon": "",
#     "processTime": 50,
#     "statusCode": "0"
# }

# %% [markdown]
# ## 3. JSON (JavaScript Object Notation)
#
# ### What is JSON
# - A lightweight data-interchange format
# - "Self-describing" and easy to understand
# - JSON format is text only
# - Language independent: can be read and used as a data format by any programming language
#
# ###  JSON Syntax Rules
# JSON syntax is derived from JavaScript object notation syntax:
# - Data is in **name/value** pairs separated by commas
# - Curly braces hold objects
# - Square brackets hold arrays
#
# ### A JSON object is:
# - **a dictionary** or
# - a **list of dictionaries**
#
# ### Useful JSON functions
# - dumps: save json object to string
# - dump: save json object to file
# - loads: load from a string in json format
# - load: load from a file in json format

# %%
# Exercise 3.1 API returns a JSON object 

parameters = {'keyword': 'yogurt', 
              'r': 'json'}

r=requests.get('https://groceries.asda.com/api/items/search', params=parameters)

# if the API call returns a successful response
if r.status_code==200:
    result = r.json()
    
    df = pd.DataFrame(result["items"])
    df.head()
# Out:
#          shelfId        shelfName         deptId            deptName isBundle  \
# 0  1215286383583          Corners  1215341888021  Yogurts & Desserts    false
# 1  1215286423096  Activia Yogurts  1215341888021  Yogurts & Desserts    false
# 2  1215286383583          Corners  1215341888021  Yogurts & Desserts    false
# 3   910000976085     Kids Yogurts  1215341888021  Yogurts & Desserts    false
# 4  1215286383583          Corners  1215341888021  Yogurts & Desserts    false
#
#   meatStickerDetails extraLargeImageURL bundledItemCount  \
# 0  8::for::£4::false                                   0
# 1  4::for::£3::false                                   0
# 2  8::for::£4::false                                   0
# 3                                                      0
# 4  8::for::£4::false                                   0
#
#                            scene7Host      cin  ... avgWeight  \
# 0  https://ui.assets-asda.com:443/dm/  6362225  ...
# 1  https://ui.assets-asda.com:443/dm/  6202233  ...
# 2  https://ui.assets-asda.com:443/dm/  6362239  ...
# 3  https://ui.assets-asda.com:443/dm/  6203595  ...
# 4  https://ui.assets-asda.com:443/dm/  6362227  ...
#
#                                          iconDetails maxQty pricePerWt  \
# 0  {'promotionalIcons': ['59600049'], 'informatio...   10.0       Each
# 1                                                 {}   10.0       Each
# 2  {'promotionalIcons': ['59600049'], 'informatio...   10.0       Each
# 3  {'promotionalIcons': ['45100001', '59600050'],...   10.0       Each
# 4  {'promotionalIcons': ['59600049'], 'informatio...   10.0       Each
#
#                                           productURL pricePerUOM  \
# 0  https://groceries.asda.com:443/api/items/view?...
# 1  https://groceries.asda.com:443/api/items/view?...
# 2  https://groceries.asda.com:443/api/items/view?...
# 3  https://groceries.asda.com:443/api/items/view?...
# 4  https://groceries.asda.com:443/api/items/view?...
#
#   searchTuningScore onSale salePrice positionChngByMargin
# 0         9486254.0  False                              0
# 1         7188797.5  False                              0
# 2         6455880.0  False                              0
# 3         5867831.0  False                              0
# 4         5107219.0  False                              0
#
# [5 rows x 45 columns]

# %%
# Exercise 3.2. Parse JSON object (a dictionary)

# convert the first 2 items to string
s = json.dumps(result["items"][0:2], indent=4)
print(s)

# load back from a string
items = json.loads(s)
items

# save to file
json.dump(result["items"], open("items.json","w"))

# load back from file
items = json.load(open("items.json","r"))
print("test loaded data\n")
len(items)
items[0]
# Out:
# [
#     {
#         "shelfId": "1215286383583",
#         "shelfName": "Corners",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "8::for::\u00a34::false",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "6362225",
#         "promoDetailFull": "8 for \u00a34",
#         "availability": "A",
#         "totalReviewCount": "15",
#         "asdaSuggest": "",
#         "itemName": "Vanilla Yogurt with Chocolate\u00a0Balls",
#         "price": "\u00a30.55",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000120228362",
#         "promoId": "ls91605",
#         "isFavourite": "false",
#         "hasAlternates": "false",
#         "wasPrice": "",
#         "brandName": "Muller Corner",
#         "promoType": "No Promo",
#         "weight": "130g",
#         "promoOfferTypeCode": "15",
#         "promoQty": "8",
#         "promoValue": "\u00a34",
#         "productAttribute": "",
#         "scene7AssetId": "4025500245221",
#         "promoDetail": "8 for \u00a34",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.8",
#         "name": "Muller Corner Vanilla Yogurt with Chocolate\u00a0Balls",
#         "avgWeight": "",
#         "iconDetails": {
#             "promotionalIcons": [
#                 "59600049"
#             ],
#             "informationalIcons": []
#         },
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000120228362",
#         "pricePerUOM": "",
#         "searchTuningScore": "9486254.0",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     },
#     {
#         "shelfId": "1215286423096",
#         "shelfName": "Activia Yogurts",
#         "deptId": "1215341888021",
#         "deptName": "Yogurts & Desserts",
#         "isBundle": "false",
#         "meatStickerDetails": "4::for::\u00a33::false",
#         "extraLargeImageURL": "",
#         "bundledItemCount": "0",
#         "scene7Host": "https://ui.assets-asda.com:443/dm/",
#         "cin": "6202233",
#         "promoDetailFull": "4 for \u00a33",
#         "availability": "O",
#         "totalReviewCount": "43",
#         "asdaSuggest": "",
#         "itemName": "Low Fat Vanilla Yogurt & Granola",
#         "price": "\u00a31.00",
#         "imageURL": "",
#         "aisleName": "Yogurts & Fromage Frais",
#         "id": "1000078311452",
#         "promoId": "ls90172",
#         "isFavourite": "false",
#         "hasAlternates": "true",
#         "wasPrice": "",
#         "brandName": "Activia",
#         "promoType": "No Promo",
#         "weight": "165g",
#         "promoOfferTypeCode": "15",
#         "promoQty": "4",
#         "promoValue": "\u00a33",
#         "productAttribute": "",
#         "scene7AssetId": "5060360502960",
#         "promoDetail": "4 for \u00a33",
#         "bundleDiscount": "0.00",
#         "avgStarRating": "4.4186",
#         "name": "Activia Low Fat Vanilla Yogurt & Granola",
#         "avgWeight": "",
#         "iconDetails": {},
#         "maxQty": "10.0",
#         "pricePerWt": "Each",
#         "productURL": "https://groceries.asda.com:443/api/items/view?itemid=1000078311452",
#         "pricePerUOM": "",
#         "searchTuningScore": "7188797.5",
#         "onSale": false,
#         "salePrice": "",
#         "positionChngByMargin": 0
#     }
# ]
# [{'shelfId': '1215286383583',
#   'shelfName': 'Corners',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'isBundle': 'false',
#   'meatStickerDetails': '8::for::£4::false',
#   'extraLargeImageURL': '',
#   'bundledItemCount': '0',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'cin': '6362225',
#   'promoDetailFull': '8 for £4',
#   'availability': 'A',
#   'totalReviewCount': '15',
#   'asdaSuggest': '',
#   'itemName': 'Vanilla Yogurt with Chocolate\xa0Balls',
#   'price': '£0.55',
#   'imageURL': '',
#   'aisleName': 'Yogurts & Fromage Frais',
#   'id': '1000120228362',
#   'promoId': 'ls91605',
#   'isFavourite': 'false',
#   'hasAlternates': 'false',
#   'wasPrice': '',
#   'brandName': 'Muller Corner',
#   'promoType': 'No Promo',
#   'weight': '130g',
#   'promoOfferTypeCode': '15',
#   'promoQty': '8',
#   'promoValue': '£4',
#   'productAttribute': '',
#   'scene7AssetId': '4025500245221',
#   'promoDetail': '8 for £4',
#   'bundleDiscount': '0.00',
#   'avgStarRating': '4.8',
#   'name': 'Muller Corner Vanilla Yogurt with Chocolate\xa0Balls',
#   'avgWeight': '',
#   'iconDetails': {'promotionalIcons': ['59600049'], 'informationalIcons': []},
#   'maxQty': '10.0',
#   'pricePerWt': 'Each',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000120228362',
#   'pricePerUOM': '',
#   'searchTuningScore': '9486254.0',
#   'onSale': False,
#   'salePrice': '',
#   'positionChngByMargin': 0},
#  {'shelfId': '1215286423096',
#   'shelfName': 'Activia Yogurts',
#   'deptId': '1215341888021',
#   'deptName': 'Yogurts & Desserts',
#   'isBundle': 'false',
#   'meatStickerDetails': '4::for::£3::false',
#   'extraLargeImageURL': '',
#   'bundledItemCount': '0',
#   'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#   'cin': '6202233',
#   'promoDetailFull': '4 for £3',
#   'availability': 'O',
#   'totalReviewCount': '43',
#   'asdaSuggest': '',
#   'itemName': 'Low Fat Vanilla Yogurt & Granola',
#   'price': '£1.00',
#   'imageURL': '',
#   'aisleName': 'Yogurts & Fromage Frais',
#   'id': '1000078311452',
#   'promoId': 'ls90172',
#   'isFavourite': 'false',
#   'hasAlternates': 'true',
#   'wasPrice': '',
#   'brandName': 'Activia',
#   'promoType': 'No Promo',
#   'weight': '165g',
#   'promoOfferTypeCode': '15',
#   'promoQty': '4',
#   'promoValue': '£3',
#   'productAttribute': '',
#   'scene7AssetId': '5060360502960',
#   'promoDetail': '4 for £3',
#   'bundleDiscount': '0.00',
#   'avgStarRating': '4.4186',
#   'name': 'Activia Low Fat Vanilla Yogurt & Granola',
#   'avgWeight': '',
#   'iconDetails': {},
#   'maxQty': '10.0',
#   'pricePerWt': 'Each',
#   'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000078311452',
#   'pricePerUOM': '',
#   'searchTuningScore': '7188797.5',
#   'onSale': False,
#   'salePrice': '',
#   'positionChngByMargin': 0}]
# test loaded data
# 60
# {'shelfId': '1215286383583',
#  'shelfName': 'Corners',
#  'deptId': '1215341888021',
#  'deptName': 'Yogurts & Desserts',
#  'isBundle': 'false',
#  'meatStickerDetails': '8::for::£4::false',
#  'extraLargeImageURL': '',
#  'bundledItemCount': '0',
#  'scene7Host': 'https://ui.assets-asda.com:443/dm/',
#  'cin': '6362225',
#  'promoDetailFull': '8 for £4',
#  'availability': 'A',
#  'totalReviewCount': '15',
#  'asdaSuggest': '',
#  'itemName': 'Vanilla Yogurt with Chocolate\xa0Balls',
#  'price': '£0.55',
#  'imageURL': '',
#  'aisleName': 'Yogurts & Fromage Frais',
#  'id': '1000120228362',
#  'promoId': 'ls91605',
#  'isFavourite': 'false',
#  'hasAlternates': 'false',
#  'wasPrice': '',
#  'brandName': 'Muller Corner',
#  'promoType': 'No Promo',
#  'weight': '130g',
#  'promoOfferTypeCode': '15',
#  'promoQty': '8',
#  'promoValue': '£4',
#  'productAttribute': '',
#  'scene7AssetId': '4025500245221',
#  'promoDetail': '8 for £4',
#  'bundleDiscount': '0.00',
#  'avgStarRating': '4.8',
#  'name': 'Muller Corner Vanilla Yogurt with Chocolate\xa0Balls',
#  'avgWeight': '',
#  'iconDetails': {'promotionalIcons': ['59600049'], 'informationalIcons': []},
#  'maxQty': '10.0',
#  'pricePerWt': 'Each',
#  'productURL': 'https://groceries.asda.com:443/api/items/view?itemid=1000120228362',
#  'pricePerUOM': '',
#  'searchTuningScore': '9486254.0',
#  'onSale': False,
#  'salePrice': '',
#  'positionChngByMargin': 0}

# %% [markdown]
# ## 4. Get Tweets
#
# Reference:
# - https://github.com/scalto/snscrape-by-location/blob/main/snscrape_by_location_tutorial.ipynb
# - https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25
#
# Note: User object is not exposed by TwitterSearchScraper any more.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#  search by keywords + time
# TwitterSearchScraper returns an interator, islice loops through the iterator

df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '"blockchain + since:2021-12-1 until:2022-1-31"').get_items(), 500))

print(len(df))
df.head()
# Out:
# 500
#                                                  url  \
# 0  https://twitter.com/CryptoAnomalous/status/148...
# 1  https://twitter.com/gerard_dache/status/148793...
# 2  https://twitter.com/Rekttrading8/status/148793...
# 3  https://twitter.com/KeanuBelieves/status/14879...
# 4  https://twitter.com/duynguy40664441/status/148...
#
#                        date  \
# 0 2022-01-30 23:59:59+00:00
# 1 2022-01-30 23:59:55+00:00
# 2 2022-01-30 23:59:54+00:00
# 3 2022-01-30 23:59:50+00:00
# 4 2022-01-30 23:59:35+00:00
#
#                                              content  \
# 0  @BradSherman do not get in the way of US techn...
# 1  Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...
# 2  @kararesurrect You are still announcing it on ...
# 3  @WatcherGuru @AffinityBSC. Being listing on a ...
# 4                         @mine_blockchain scam mnet
#
#                                      renderedContent                   id  \
# 0  @BradSherman do not get in the way of US techn...  1487938677535907845
# 1  Congrats to Bill Rockwood Jr, Esq., MBA, J.D.,...  1487938658023919619
# 2  @kararesurrect You are still announcing it on ...  1487938655159140353
# 3  @WatcherGuru @AffinityBSC. Being listing on a ...  1487938639820693508
# 4                         @mine_blockchain scam mnet  1487938575937126400
#
#                                                 user  replyCount  \
# 0  {'username': 'CryptoAnomalous', 'id': 53283913...           0
# 1  {'username': 'gerard_dache', 'id': 256189693, ...           0
# 2  {'username': 'Rekttrading8', 'id': 14337294741...           0
# 3  {'username': 'KeanuBelieves', 'id': 1425210713...           0
# 4  {'username': 'duynguy40664441', 'id': 14595808...           1
#
#    retweetCount  likeCount  quoteCount  ...  media retweetedTweet quotedTweet  \
# 0             0          0           0  ...   None           None        None
# 1             0          7           3  ...   None           None        None
# 2             0          0           0  ...   None           None        None
# 3             0          1           0  ...   None           None        None
# 4             0          0           0  ...   None           None        None
#
#   inReplyToTweetId                                      inReplyToUser  \
# 0              NaN                                               None
# 1              NaN                                               None
# 2     1.487820e+18  {'username': 'TraderZetas', 'id': 147446459766...
# 3     1.487907e+18  {'username': 'WatcherGuru', 'id': 138749787175...
# 4     1.486773e+18  {'username': 'mine_blockchain', 'id': 13995421...
#
#                                       mentionedUsers coordinates place  \
# 0  [{'username': 'BradSherman', 'id': 30216513, '...        None  None
# 1                                               None        None  None
# 2                                               None        None  None
# 3  [{'username': 'WatcherGuru', 'id': 13874978717...        None  None
# 4  [{'username': 'mine_blockchain', 'id': 1399542...        None  None
#
#   hashtags cashtags
# 0     None     None
# 1     None     None
# 2     None     None
# 3  [ADAPT]     None
# 4     None     None
#
# [5 rows x 27 columns]

# %%
df.content[80:100]
# Out:
# 80    How #bitcoin adoption could bring major prospe...
# 81    Cooper Rogers is here to save the #Metaverse w...
# 82    @sansiniestro Es que depende del grado de inte...
# 83    (1/19) Sirin Labs raised 205,000 $ETH to devel...
# 84    Why do games on the blockchain always have to ...
# 85    @Colten____ Yeah man! Get in for the art and s...
# 86    Abuse and harassment on the blockchain https:/...
# 87    @ZJhonni eu tbm n entendo mto bem nao mano, ma...
# 88    @HerissonJeune @sw_remi @neoman42 @Scipionista...
# 89    @spiderzero06 @veve_official @ecomi_ Feel you ...
# 90    This is awesome. I love Bitmart ideology towar...
# 91    @Conta_genrica sabotage the NFT economy by re-...
# 92    Like a newbie I incorrectly listed our lil' Sh...
# 93    Crypto Job: (Software Engineer (Backend) - Blo...
# 94    @Ciriyan1 @VinsmokeSanjiMD @TobbyKitty Hepsi t...
# 95    .@DeFiChain Mobile Wallet v1.1.0 is now availa...
# 96    Crypto Job: (Senior Software Engineer (Backend...
# 97    Chainlink(LINK) Price is Attempting a Huge Mov...
# 98    I'm looking at @Aleph__Zero - just launched DA...
# 99    Altcoin Roundup: Cross-chain bridge tokens moo...
# Name: content, dtype: object

# %%
# search by user

df = pd.DataFrame(itertools.islice(sntwitter.TwitterUserScraper(
    '""').get_items(), 500))

print(len(df))
df.tail()

# %% [markdown]
# ## 5. Tweepy
# - Tweepy is a python library to access Twitter API.
# - `pip install tweepy`
# - The Tweepy documentation has detailed explanations: https://docs.tweepy.org/en/stable/
# - You need to apply for a developer account from here: https://developer.twitter.com/en/apply-for-access

# %%
import tweepy
import csv
import datetime

# https://docs.tweepy.org/en/stable/auth_tutorial.html

CONSUMER_KEY='c5vuI4xawiuos3BKW9UXZ8FFY'
CONSUMER_SECRET='7kNtpN1gSIYEOygD2fnZNNpkZRfoVRX1ib8UZrHFGyzAkulobw'
ACCESS_KEY='1453412544996073473-zPPYVT0f1z6e0xKAs3vCzx1wWpedNd'
ACCESS_SECRET='NmdQ2B5xtvJLOJgmW0b69ebquTLzCwAguGxsG6HRRp9Y2'

auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
api=tweepy.API(auth)

# %%
# Take a look at the public tweets from your account's home timeline 

public_tweets = api.home_timeline()
print(len(public_tweets))
for tweet in public_tweets[:2]:
    print(tweet.text)
# Out:
# 20
# #Beijing2022 concluded on Sunday with the closing ceremony. Here’s the overall medal count. 🥇 Look back at this yea… https://t.co/hgNINT0RuA
# Airport improvements, new hotels, solar energy and water projects: Many Caribbean islands are investing for the pos… https://t.co/cQv3KnjpjL

# %%
# is this useful information?
# Let's take a close look at ONE tweet json

public_tweets[1]
# there's no way to figure this out
# Out:
# Status(_api=<tweepy.api.API object at 0x7fbaea24d730>, _json={'created_at': 'Mon Feb 21 00:00:17 +0000 2022', 'id': 1495548895245570057, 'id_str': '1495548895245570057', 'text': 'Airport improvements, new hotels, solar energy and water projects: Many Caribbean islands are investing for the pos… https://t.co/cQv3KnjpjL', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cQv3KnjpjL', 'expanded_url': 'https://twitter.com/i/web/status/1495548895245570057', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 807095, 'id_str': '807095', 'name': 'The New York Times', 'screen_name': 'nytimes', 'location': 'New York City', 'description': 'News tips? Share them here: https://t.co/ghL9OoYKMM', 'url': 'http://t.co/ahvuWqicF9', 'entities': {'url': {'urls': [{'url': 'http://t.co/ahvuWqicF9', 'expanded_url': 'http://www.nytimes.com/', 'display_url': 'nytimes.com', 'indices': [0, 22]}]}, 'description': {'urls': [{'url': 'https://t.co/ghL9OoYKMM', 'expanded_url': 'http://nyti.ms/2FVHq9v', 'display_url': 'nyti.ms/2FVHq9v', 'indices': [28, 51]}]}}, 'protected': False, 'followers_count': 51677701, 'friends_count': 870, 'listed_count': 213036, 'created_at': 'Fri Mar 02 20:41:42 +0000 2007', 'favourites_count': 18840, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 463536, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/807095/1584666392', 'profile_link_color': '607696', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 23, 'favorite_count': 91, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 2, 21, 0, 0, 17, tzinfo=datetime.timezone.utc), id=1495548895245570057, id_str='1495548895245570057', text='Airport improvements, new hotels, solar energy and water projects: Many Caribbean islands are investing for the pos… https://t.co/cQv3KnjpjL', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/cQv3KnjpjL', 'expanded_url': 'https://twitter.com/i/web/status/1495548895245570057', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='SocialFlow', source_url='http://www.socialflow.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7fbaea24d730>, _json={'id': 807095, 'id_str': '807095', 'name': 'The New York Times', 'screen_name': 'nytimes', 'location': 'New York City', 'description': 'News tips? Share them here: https://t.co/ghL9OoYKMM', 'url': 'http://t.co/ ...

# %%
# make it look better
# convert to string
json_str = json.dumps(public_tweets[0]._json)

# deserialise string into python object
parsed = json.loads(json_str)

print(json.dumps(parsed, indent=4, sort_keys=True))
# Now we can have a better idea of the clustered relations of the json object
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Mon Feb 21 00:15:07 +0000 2022",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     0,
#                     12
#                 ],
#                 "text": "Beijing2022"
#             }
#         ],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/i/web/status/1\u2026",
#                 "expanded_url": "https://twitter.com/i/web/status/1495552630197784579",
#                 "indices": [
#                     117,
#                     140
#                 ],
#                 "url": "https://t.co/hgNINT0RuA"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 62,
#     "favorited": false,
#     "geo": null,
#     "id": 1495552630197784579,
#     "id_str": "1495552630197784579",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 19,
#     "retweeted": false,
#     "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#     "text": "#Beijing2022 concluded on Sunday with the closing ceremony. Here\u2019s the overall medal count. \ud83e\udd47 Look back at this yea\u2026 https://t.co/hgNINT0RuA",
#     "truncated": true,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Fri Mar 02 20:41:42 +0000 2007",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "News tips? Share them here: https://t.co/ghL9OoYKMM",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "nyti.ms/2FVHq9v",
#                         "expanded_url": "http://nyti.ms/2FVHq9v",
#                         "indices": [
#                             28,
#                             51
#                         ],
#                         "url": "https://t.co/ghL9OoYKMM"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "nytimes.com",
#                         "expanded_url": "http://www.nytimes.com/",
#                         "indices": [
#                             0,
#                             22
#                         ],
#                         "url": "http://t.co/ahvuWqicF9"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 18840,
#         "follow_request_sent": false,
#         "followers_count": 51677701,
#         "following": true,
#         "friends_count": 870,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 807095,
#         "id_str": "807095",
#         "is_translation_enabled": true,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 213036,
#         "location": "New York City",
#         "name": "The New York Times",
#         "notifications": false,
#         "profile_background_color": "131516",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/807095/1584666392",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1098244578472280064/gjkVMelR_normal.png",
#         "profile_link_color": "607696",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "nytimes",
#         "statuses_count": 463536,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": "http://t.co/ahvuWqicF9",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %% [markdown]
# ### 5.1. Get tweets from users' timeline
# - Make a Timeline call to retrieve the most recent 3200 tweets by a user (a rule set by Twitter).
#     - Note: the time range you get depends on how often the user posts tweets.
# - Parameters for the timeline call
#     - `count`: the number of results to try and retrieve per page. Maximum is 200.
#     - Make multiple calls to retrieve the 3200 tweets.
#     - `tweet_mode`:swaps the text index for full_text, and prevents a primary tweet longer than 140 characters from being truncated.
# - Variables of tweet objects
#     - https://docs.tweepy.org/en/stable/api.html#tweepy-api-twitter-api-wrapper

# %%
# Get the first five tweets of a user.
timeline = api.user_timeline(screen_name="KelloggCompany",count=5,tweet_mode="extended")

for status in timeline:
    print (status.id)
    print (status.full_text)
# Out:
# 1494058763275354112
# From lighter, resealable packaging to refillable cereal stations, we’re making meaningful strides toward our #BetterDays commitment of  100% reusable, recyclable or compostable packaging by the end of 2025. Learn more: https://t.co/2pxNDcxmtT https://t.co/UsupSea6FL
# 1494043410335944708
# Since 2015, we’ve reduced greenhouse gas emissions by the equivalent of removing nearly 3.2 billion cars off the road!  Learn more about our commitment to nurture the planet by reducing GHG emissions: https://t.co/H1DvVjslfp
# #BetterDays https://t.co/L8ArCTAS6X
# 1493979924725653507
# Helping kids and families lead filled and fulfilled lives is why we’re committed to creating #BetterDays for our people and planet. We’re honored to support @Act4HlthyKids in their mission to support kids in underserved communities. https://t.co/pr6W3Z33R6
# 1493694554222075918
# What if we could pay farmers for the greenhouse gas emissions they reduce by implementing climate-positive practices?
# We can, thanks to @RegrowAg’s Measurement, Reporting, + Verification platform + Kellogg’s new #KelloggsInGrained program!
# #BetterDays https://t.co/bY4rsi2z3q
# 1493694549838991365
# Tackling climate change can’t be done alone!  That’s why we are partnering w/ @RegrowAg, @SyngentaUS + U.S. rice farmers to reduce greenhouse gas emissions on farms over the next 5 years.  #BetterDays #KelloggsInGrained https://t.co/lgGKVH6qK7

# %%
# Step 1: get a list of tweets 
# Step 2: extract the varaibles you want

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth)
    
    # initialize the first call
    alltweets=[]
    new_tweets=api.user_timeline(screen_name=user_name, count=200)
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  #next time start from the oldest one minus one 
    
    # continue to get tweets
    while len(new_tweets)>0:  
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(screen_name=user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
    
    # extract the variables you want
    outtweets = [[tweet.id_str, tweet.user.name, tweet.created_at, tweet.user.followers_count,
                  tweet.text.encode("utf-8")] for tweet in alltweets]
            
    # write out your variables
    with open('%s_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","user_name","created_at","followers","text"])
        writer.writerows(outtweets)
    pass

# use your function
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1399719994724864010
# ...400 tweets downloaded so far
# getting tweets before 1337041811412488197
# ...600 tweets downloaded so far
# getting tweets before 1257656292014993407
# ...800 tweets downloaded so far
# getting tweets before 1195344248163491839
# ...1000 tweets downloaded so far
# getting tweets before 1133722853013114879
# ...1200 tweets downloaded so far
# getting tweets before 1040045464765325311
# ...1400 tweets downloaded so far
# getting tweets before 961706244900818943
# ...1600 tweets downloaded so far
# getting tweets before 902881450592231423
# ...1800 tweets downloaded so far
# getting tweets before 842721640182140927
# ...2000 tweets downloaded so far
# getting tweets before 776789658802028543
# ...2197 tweets downloaded so far
# getting tweets before 725360392512364548
# ...2395 tweets downloaded so far
# getting tweets before 672728657132175360
# ...2595 tweets downloaded so far
# getting tweets before 634431301207068671
# ...2794 tweets downloaded so far
# getting tweets before 565228691689840640
# ...2994 tweets downloaded so far
# getting tweets before 486572969007665151
# ...3192 tweets downloaded so far
# getting tweets before 357576800299266048
# ...3242 tweets downloaded so far
# getting tweets before 337170261273100288
# ...3242 tweets downloaded so far

# %%
# Take a look at the table you got
df= pd.read_csv('KelloggCompany_tweet.csv', header=0)
df.head()

# how many tweets we get?
len(df)

# The following tweet is a retweet. Take a look at the text.
# The index of this retweet is based on the table generated previously
# if you run at a different time, you will see a differet tweet
# try to find a retweet and compare the text with the actual tweet
# You can find each tweet on Twitter by its ID.
df.text[34]
# Out:
#                     id        user_name           created_at  followers  \
# 0  1491416753037279234  Kellogg Company  2022-02-09 14:20:37      76708
# 1  1491151362389905409  Kellogg Company  2022-02-08 20:46:03      76708
# 2  1489299648720388102  Kellogg Company  2022-02-03 18:08:00      76708
# 3  1489248636819021832  Kellogg Company  2022-02-03 14:45:18      76708
# 4  1488887938863800321  Kellogg Company  2022-02-02 14:52:01      76708
#
#                                                 text
# 0  b'Is it worth getting your hand stuck?  Of cou...
# 1  b"Check out this in-depth and  wide-ranging di...
# 2  b'We\xe2\x80\x99re honored to be on @FortuneMa...
# 3  b'"We\xe2\x80\x99ve got this wonderful resourc...
# 4  b"For many kids, a snow day is all about fun -...
# 3220
# "b'RT @foodbanking: Food loss &amp; waste is costly for producers, takes up space in landfills, and emits harmful greenhouse gases.\\n\\nIn our blog o\\xe2\\x80\\xa6'"

# %% [markdown]
# ### 5.2. Deal with truncated text
# - For text mining on Twitter, it is important to get the full text.
#     - Full text would be essential for topic modeling and sentiment analysis.
#     - Full text is also important for extracting mention networks (note the previous example).
# - Use the `tweet_mode="extended"` when calling a user's timeline.
#     - When using extended mode, the `text` attribute of Status objects returned is replaced by a `full_text` attribute, which contains the entire untruncated text of the Tweet.
# - Full text for tweets that are retweets.
#     - If the tweet is a retweet, the full_text is still truncated.
#     - We need to access the full text through `retweeted_status` attribute, which is a status object itself.
# - For reference: https://docs.tweepy.org/en/stable/extended_tweets.html

# %%
# Let's deal with retweets

def get_all_tweets(user_name):
    auth=tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
    auth.set_access_token(ACCESS_KEY,ACCESS_SECRET)
    api=tweepy.API(auth,wait_on_rate_limit=True)

    alltweets=[]
    new_tweets=api.user_timeline(screen_name = user_name, count=200,tweet_mode="extended")
    alltweets.extend(new_tweets)
    oldest=alltweets[-1].id-1  
    
    # set date condition
    startDate = datetime.datetime(2021, 1, 1, 0, 0, 0, tzinfo=datetime.timezone.utc)
    while new_tweets[-1].created_at > startDate:
        print ("getting tweets before", oldest)
        new_tweets = api.user_timeline(screen_name = user_name,count=200, max_id=oldest)
        alltweets.extend(new_tweets)
        oldest=alltweets[-1].id-1
        print("...{} tweets downloaded so far".format(len(alltweets)))
        
    # check if it's a retweet
    # When using extended mode with a Retweet, the full_text attribute of the Status object may be truncated    
    # However, since the retweeted_status attribute (of a Status object that is a Retweet) is itself a Status object
    # the full_text attribute of the Retweeted Status object can be used instead.
    
    outtweets_all=[]
    for tweet in alltweets:
        status = api.get_status(tweet.id, tweet_mode="extended")
        
        if hasattr(status, "retweeted_status"):  # is a retweet
            full_text=status.retweeted_status.full_text.encode("utf-8")
            
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            tweet.retweeted_status.user.name,tweet.retweeted_status.user.screen_name,tweet.retweeted_status.user.description]
            outtweets_all.append(outtweets)
  
        else: # not a retweet
            full_text=status.full_text.encode("utf-8")
                    
            outtweets=[
            # tweet content
            tweet.id_str, tweet.created_at,full_text,
            # user features
            tweet.user.name, tweet.user.screen_name, tweet.user.followers_count, 
            # retweet features
            "no value","no value","no value"]
            outtweets_all.append(outtweets)

    with open('%s_full_tweet.csv' % user_name,'w') as outputfile: 
        writer=csv.writer(outputfile)
        writer.writerow(["id","created_at","full_text",
                        "user.name","user.screen_name","user.followers_count",
                        "retweeted_status.user.name","retweeted_status.user.screen_name","retweeted_status.user.description"])
        writer.writerows(outtweets_all)

        
if __name__ == '__main__':
    #pass in the username of the account you want to download
    get_all_tweets("KelloggCompany")
# Out:
# getting tweets before 1399719994724864010
# ...400 tweets downloaded so far

# %%
df= pd.read_csv('KelloggCompany_full_tweet.csv', header=0)
df.head()
len(df)
# plese compare this full text with the above truncated text, what differences can you find?
df.full_text[34]
# Out:
#                     id           created_at  \
# 0  1491416753037279234  2022-02-09 14:20:37
# 1  1491151362389905409  2022-02-08 20:46:03
# 2  1489299648720388102  2022-02-03 18:08:00
# 3  1489248636819021832  2022-02-03 14:45:18
# 4  1488887938863800321  2022-02-02 14:52:01
#
#                                            full_text        user.name  \
# 0  b'Is it worth getting your hand stuck?  Of cou...  Kellogg Company
# 1  b'Check out this in-depth and  wide-ranging di...  Kellogg Company
# 2  b'We\xe2\x80\x99re honored to be on @FortuneMa...  Kellogg Company
# 3  b'"We\xe2\x80\x99ve got this wonderful resourc...  Kellogg Company
# 4  b"For many kids, a snow day is all about fun -...  Kellogg Company
#
#   user.screen_name  user.followers_count retweeted_status.user.name  \
# 0   KelloggCompany                 76708                   no value
# 1   KelloggCompany                 76708                   no value
# 2   KelloggCompany                 76708                   no value
# 3   KelloggCompany                 76708                   no value
# 4   KelloggCompany                 76708                   no value
#
#   retweeted_status.user.screen_name retweeted_status.user.description
# 0                          no value                          no value
# 1                          no value                          no value
# 2                          no value                          no value
# 3                          no value                          no value
# 4                          no value                          no value
# 400
# "b'Food loss &amp; waste is costly for producers, takes up space in landfills, and emits harmful greenhouse gases.\\n\\nIn our blog on @CGF_The_Forum, see how partnerships between #FoodProducers and #FoodBanks can alleviate hunger and mitigate climate change. #IDAFLW\\nhttps://t.co/xIOT0Hjlac'"

# %% [markdown]
# ### 5.3. Build Twitter networks
# - **Follower-followee network**
#     - If you have a list of user accounts, you may retrive the pairwise boolean values of following relations.
#     - Parameters
#         * `source_id` – The user_id of the subject user.
#         * `source_screen_name` – The screen_name of the subject user.
#         * `target_id` – The user_id of the target user.
#         * `target_screen_name` – The screen_name of the target user.
# - **Retweet network**
#     - Retweeted accounts can be extracted while scraping the API.
#     - Or retweeted accounts can be extracted from the text.
# - **Mention network**
#     - Can be extracted from the full text.

# %%
# How to scrape the follower-followee network?
# we can directly retrieve a bollean value 

dog="Microsoft"
cat="Oracle"

is_following = api.get_friendship(source_screen_name=cat,target_screen_name=dog)
print(is_following[1].following)

# Question: how to get the adjacency matrix of a follower-followee network?
# Out:
# False

# %% [markdown]
# ### 5.4 Keywords search

# %%
# Define the search term and the date_since date as variables
search_words = "blockchain"
date_since = "2021-11-01"

# Collect tweets
tweets = tweepy.Cursor(api.search_tweets,
              q=search_words,
              lang="en",
              since=date_since).items(5)


# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# Unexpected parameter: since
# @DeFiDiscussion @ludo Many games that involve blockchain are often not entertaining enough and end up being played… https://t.co/6eM0YbOUyo
# RT @CardanoFeed: Cardano Enters Top 3 of Most Developed Coins on Crypto Market
#
# #Cardano #cardanofeed #ADA #crypto #cardanocommunity #bitc…
# RT @POODLETOKEN: $POODL is available for everyone, any network. From virtually any #crypto
#
# $ETH $BTC $SOL $ONE $ZIL $BNB
#
# It doesn't matt…
# RT @AgeOfZalmoxis: Our Whitepaper is out!
# https://t.co/v0PnvjQua8
#
# Be part of the community:
# https://t.co/2WNZTfQy4y
#
# @RomanianAcademy @ben…
# RT @HiRezTheRapper: I AM GOING TO BE LAUNCHING LIMITED LIFETIME MEMBERSHIPS TO ALL MY IRL/META EVENTS FOR @HogHomies. HOLDERS WILL GET FREE…

# %% [markdown]
# ##### Twitter data resources
# https://github.com/echen102/us-pres-elections-2020 <br>
# https://github.com/echen102/COVID-19-TweetIDs
