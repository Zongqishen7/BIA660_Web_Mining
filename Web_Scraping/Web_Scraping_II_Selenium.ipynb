# %% [markdown]
# # <center>Web Scraping II -- Dyamic Web Page Scraping with Selenium </center>
#
# References:
# - http://selenium-python.readthedocs.io/getting-started.html
# - https://www.scrapingbee.com/blog/selenium-python/
# - https://www.selenium.dev/documentation/webdriver/

# %% [markdown]
# ## 1. Why Selenium
# - When **Requests + BeautifulSoup** don't work?
#   - Elements in a web page loaded **asynchronously**
#      * while requests.get(url) can only return the initial content
#      * you may need to wait for a while to get web content fully loaded
#   - You need to **interact with the page** to get some content loaded, e.g.
#      * scroll down to load more
#      * click a button like "more"
#      * close a pop-up ad window
#      * fill a form
# - Example: https://www.quora.com/topic/Machine-Learning

# %%
# Exercise 1.1. Scape quora page using requests+beautifulsoup

# import requests package
import requests    
import time

# import BeautifulSoup from package bs4 (i.e. beautifulsoup4)
from bs4 import BeautifulSoup   

page = requests.get("https://www.quora.com/topic/Machine-Learning")    # send a get request to the web page


if page.status_code==200:      

    soup = BeautifulSoup(page.content, 'html.parser')
    print(soup.prettify())

    
    # get all questions
    questions=soup.select("span.q-box.qu-userSelect--text")
    
    for i, q in enumerate(questions):
        print(i, q.get_text())
        #print("\n")

# Note: nothing is returned. Do you know why? #doesn't work for the dynimic page
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" style="padding: 0; margin: 0;">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="https://qsf.fs.quoracdn.net/-4-images.favicon-new.ico-26-07ecf7cd341b6919.ico" rel="icon"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-27-ae5f6cbbbbf75641.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-vendor-28-d20d842af6d9ecf4.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-27-7f0f168ba5aab5c8.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-page-TopicPageLoadable-27-da815b435c5ec564.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Multifeed-27-55ce2eb5f31f9a7d.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-TopicTab-ReadWrite-27-6af99ef19d0bd2af.webpack" rel="preload"/>
#   <link as="script" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-63ac433ecdf9c2cd.webpack" rel="preload"/>
#   <link as="style" href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-main.css-28-8bc172b790f24efd.webpack" rel="preload"/>
#   <link href="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-main.css-28-8bc172b790f24efd.webpack" id="ans-frontend-main-css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    window.isReactPage = true;window.isReactLoaded = true;window.ansFrontendRelayWebpackManifest = {"common":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-27-7f0f168ba5aab5c8.webpack","common-LoggedOut":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-63ac433ecdf9c2cd.webpack","common-Mweb":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-Mweb-27-7ad7e7ea1ef52085.webpack","common-NativeApp":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-NativeApp-27-1fdfbfd50b069776.webpack","common-secondary":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-secondary-27-9f44180264369c4e.webpack","component-ActivationDeckInner":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-ActivationDeckInner-27-49fafc0846c300be.webpack","component-AdCTABanner":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AdCTABanner-27-80a4cc48f46a0a7a.webpack","component-AdminTools-profile":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AdminTools-profile-27-8a480a5efcd6f4cf.webpack","component-AnnouncementBundle":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AnnouncementBundle-27-a04846c402a6fb52.webpack","component-AnswerEditor":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AnswerEditor-27-f2c9ecc978cf345f.webpack","component-AnswerFooter":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AnswerFooter-27-5ae6daf753f2e709.webpack","component-AnswerPageFooter":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AnswerPageFooter-27-8cd620f4a86cb3ae.webpack","component-AppRootTabHeader":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-AppRootTabHeader-27-b731e3e7ecda34d4.webpack","component-CollapseAnswerSection":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-CollapseAnswerSection-27-fa0165c4a013e8c9.webpack","component-Comments":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Comments-27-4265c9fcf22c2a78.webpack","component-CookieBanner":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-CookieBanner-27-0b2d677fda7fb60e.webpack","component-DesktopMessagesDock":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-DesktopMessagesDock-27-86c59006089b74a2.webpack","component-FeedSwitcher":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-FeedSwitcher-27-74ed9e938b2b8ce1.webpack","component-FollowTribeSuggestionsList":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-FollowTribeSuggestionsList-27-e3852efbdee32c44.webpack","component-Hovercards":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Hovercards-27-6acb21728a349753.webpack","component-ImageViewer":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-ImageViewer-27-180f0570d35b7d76.webpack","component-LightweightSurvey":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-LightweightSurvey-27-c108154ab32e6a5f.webpack","component-Login":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Login-27-d02aa2c025f0f018.webpack","component-MobileLookup":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-MobileLookup-27-03bd014610ece85e.webpack","component-Modals-AdsConsumer":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsConsumer-27-a537d8ecf246b44d.webpack","component-Modals-AdsManager":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsManager-27-16804079445467a9.webpack","component-Modals-AskQuestion":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-AskQuestion-27-fb159137f286daac.webpack","component-Modals-Business":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-Business-27-77a9c2e3bf485f30.webpack","component-Modals-EarningsPrograms":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-EarningsPrograms-27-9b4b183d316dc4cb.webpack","component-Modals-Editor":"https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Modals-Editor-27-843e7c39f53dfee0.we ...
# window.ansFrontendRelayWebpackManifestMapping = [];
# var includedChunks = window.ansFrontendRelayWebpackIncludedChunks;
# window.ansFrontendRelayWebpackIncludedChunks = (includedChunks || []).concat(["vendor","common","page-TopicPageLoadable","component-Multifeed","component-TopicTab-ReadWrite","common-LoggedOut"]);
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settingsStrictMode = false;
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.earlySettings = {"formkey": "206b69ef5667ce5f915802b92f3f3cd1", "errorSamplingRate": 1.0, "interfaceLanguageCode": "en", "isDevCode": false, "isMobileAppPrefetched": false, "topLevelNid": 0, "react_console_log_perf_info": false, "subdomainSuffix": "quora.com", "windowId": "react_clkcqfteangkltty", "rootClsKey": "TopicPage", "rootQueryVariables": {"tid": 948, "initialTab": "read"}, "rootProps": {"tid": 948, "initialTab": "read"}, "inlineQueryEnabled": true, "inlineQueryHashes": {"e138e05e2c88cb102a1d14996556420c775473329fce63ffde22a1be54648caf": true, "95ffea39c8cd3de624de2cedcd051bc9a56bc7720c8e775c9debb3a23bba70b4": true, "d37d7a6d9eae37673abc0afdcb72e868fe797f31d59576e46254fd05706cbc80": true}, "pageShellInfo": null, "shouldServerRender": false, "hasIndicator": true, "isServiceWorkerConstructed": false};
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = {"inlineQueryResults": {}};
#   </script>
#   <script id="entryjs" type="text/javascript">
#    !function(t){function n(n){for(var e,o,i=n[0],u=n[1],c=0,a=[];c<i.length;c++)o=i[c],Object.prototype.hasOwnProperty.call(r,o)&&r[o]&&a.push(r[o][0]),r[o]=0;for(e in u)Object.prototype.hasOwnProperty.call(u,e)&&(t[e]=u[e]);for(s&&s(n);a.length;)a.shift()()}var e={},r={entry:0};function o(t){return window.ansFrontendRelayWebpackManifest[t]}function i(n){if(e[n])return e[n].exports;var r=e[n]={i:n,l:!1,exports:{}};return t[n].call(r.exports,r,r.exports,i),r.l=!0,r.exports}i.e=function(t){if(0===r[t])return Promise.resolve();if(r[t])return r[t][2];var n=new Promise((function(n,e){r[t]=[n,e]}));if(r[t][2]=n,-1!=window.ansFrontendRelayWebpackIncludedChunks.indexOf(t))return n;var e=document.getElementsByTagName("head")[0];(c=document.createElement("script")).charset="utf-8",c.timeout=120,i.nc&&c.setAttribute("nonce",i.nc),c.src=o(t);var u=new Error;a=function(n){c.onerror=c.onload=null,clearTimeout(s);var e=r[t];if(0!==e){if(e){var o=n&&("load"===n.type?"missing":n.type),i=n&&n.target&&n.target.src;u.message="Loading chunk "+t+" failed.\n("+o+": "+i+")",u.name="ChunkLoadError",u.type=o,u.request=i,e[1](u)}r[t]=undefined}};var c,a,s=setTimeout((function(){a({type:"timeout",target:c})}),12e4);return c.onerror=c.onload=a,e.appendChild(c),n},i.m=t,i.c=e,i.d=function(t,n,e){i.o(t,n)||Object.defineProperty(t,n,{enumerable:!0,get:e})},i.r=function(t){"undefined"!==typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(t,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(t,"__esModule",{value:!0})},i.t=function(t,n){if(1&n&&(t=i(t)),8&n)return t;if(4&n&&"object"===typeof t&&t&&t.__esModule)return t;var e=Object.create(null);if(i.r(e),Object.defineProperty(e,"default",{enumerable:!0,value:t}),2&n&&"string"!=typeof t)for(var r in t)i.d(e,r,function(n){return t[n]}.bind(null,r));return e},i.n=function(t){var n=t&&t.__esModule?function(){return t["default"]}:function(){return t};return i.d(n,"a",n),n},i.o=function(t,n){return Object.prototype.hasOwnProperty.call(t,n)},i.p="/",i.oe=function(t){throw console.error(t),t};var u=window.ansFrontendRelayWebpackJsonpFunction=window.ansFrontendRelayWebpackJsonpFunction||[],c=u.push.bind(u);u.push=n,u=u.slice();for(var a=0;a<u.length;a++)n(u[a]);var s=c;i(i.s=0)}({0:function(t,n,e){t.exports=e("oqNQ")},"8oxB":function(t,n){var e,r,o=t.exports={};function i(){throw new Error("setTimeout has not been defined")}function u(){throw new Error("clearTimeout has not been defined")}function c(t){if(e===setTimeout)return setTimeout(t,0);if((e===i||!e)&&setTimeout)return e=setTimeout,setTimeout(t,0);try{return e(t,0)}catch(n){try{return e.call(null,t,0)}catch(n){return e.call(this,t,0)}}}!function(){try{e="function"===typeof setTimeout?setTimeout:i}catch(t){e=i}try{r="function"===typeof clearTimeout?clearTimeout:u}catch(t){r=u}}();var a,s=[],f=!1,l=-1;function h(){f&&a&&(f=!1,a.length?s=a.concat(s):l=-1,s.length&&d())}function d(){if(!f){var t=c(h);f=!0;for(var n=s.length;n;){for(a=s,s=[];++l<n;)a&&a[l].run();l=-1,n=s.length}a=null,f=!1,function(t){if(r===clearTimeout)return clearTimeout(t);if((r===u||!r)&&clearTimeout)return r=clearTimeout,clearTimeout(t);try{r(t)}catch(n){try{return r.call(null,t)}catch(n){return r.call(this,t)}}}(t)}}function p(t,n){this.fun=t,this.array=n}function v(){}o.nextTick=function(t){var n=new Array(arguments.length-1);if(arguments.length>1)for(var e=1;e<arguments.length;e++)n[e-1]=arguments[e];s.push(new p(t,n)),1!==s.length||f||c(d)},p.prototype.run=function(){this.fun.apply(null,this.array)},o.title="browser",o.browser=!0,o.env={},o.argv=[],o.version="",o.versions={},o.on=v,o.addListener=v,o.once=v,o.off=v,o.removeListener=v,o.removeAllListeners=v,o.emit=v,o.prependListener=v,o.prependOnceListener=v,o.listeners=function(t){return[]},o.binding=function(t){throw new Error("process.binding is not supported")},o.cwd=function(){return"/"},o.chdir=function(t){throw new Error("process.chdir is not supported")},o.umask=function(){return 0}},E2g8:function(t,n,e){(function(n,e){va ...
#   </script>
#   <script async="1" defer="1" onerror="addAssetErr(this.src)" src="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-vendor-28-d20d842af6d9ecf4.webpack" type="text/javascript">
#   </script>
#   <script async="1" defer="1" onerror="addAssetErr(this.src)" src="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-27-7f0f168ba5aab5c8.webpack" type="text/javascript">
#   </script>
#   <script async="1" defer="1" onerror="addAssetErr(this.src)" src="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-page-TopicPageLoadable-27-da815b435c5ec564.webpack" type="text/javascript">
#   </script>
#   <script async="1" defer="1" onerror="addAssetErr(this.src)" src="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-Multifeed-27-55ce2eb5f31f9a7d.webpack" type="text/javascript">
#   </script>
#   <script async="1" defer="1" onerror="addAssetErr(this.src)" src="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-component-TopicTab-ReadWrite-27-6af99ef19d0bd2af.webpack" type="text/javascript">
#   </script>
#   <script async="1" defer="1" onerror="addAssetErr(this.src)" src="https://qsc.fs.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-63ac433ecdf9c2cd.webpack" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.runApp();
#   </script>
#   <script type="text/javascript">
#    function getLoggingUrl(){var e="/ajax/page_bounce_POST";return"quora.com"==window.ansFrontendGlobals.earlySettings.subdomainSuffix?"https://log.quora.com/ajax/page_bounce_POST":e}function logPageBounce(e){if(window.isReactPage&&!window.reportedPageLoadBounce&&!window.ansFrontendGlobals.earlySettings.isMobileAppPrefetched&&!window.ansFrontendGlobals.earlySettings.isPrefetchedPage){window.reportedPageLoadBounce=!0;var n=window.ansFrontendGlobals.earlySettings.windowId,o={url:window.location.href,windowId:n,wasViewed:window.wasViewed};if(window.performance&&window.performance.timing){var a=window.performance.timing.navigationStart;a&&(o.unloadTime=Date.now()-a,o.cause=e)}var i=getLoggingUrl(),t=window.ansFrontendGlobals.earlySettings.formkey,d=[{category:"unload_before_page_ready",data:o,time:1e3*Date.now()}];try{var r=new window.FormData;r.append("messages",JSON.stringify(d)),r.append("formkey",t),window.navigator.sendBeacon(i,r)}catch(w){var s=new XMLHttpRequest;s.open("POST",i,!0),s.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),
# s.setRequestHeader("Quora-Formkey",t);var g="messages="+encodeURIComponent(JSON.stringify(d));s.setRequestHeader("Accept","*/*"),s.send(g.replace(/%20/g,"+"))}}}window.wasViewed="visible"===document.visibilityState,window.addEventListener("beforeunload",function(e){logPageBounce("beforeunload")}),window.addEventListener("pagehide",function(e){logPageBounce("pagehide")}),window.addEventListener("visibilitychange",function(e){"hidden"===document.visibilityState?logPageBounce("visibilitychange_hidden"):window.wasViewed=!0});
#   </script>
#   <script type="text/javascript">
#    var assetErrs=[];document.addEventListener("DOMContentLoaded",function(e){setTimeout(function(){if(0!==assetErrs.length){var e="assets="+encodeURIComponent(JSON.stringify(assetErrs)),t=new XMLHttpRequest;t.open("POST","/ajax/log_browser_asset_load_error_3RD_PARTY_POST",!0),t.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),t.setRequestHeader("Accept","*/*"),t.send(e.replace(/%20/g,"+"))}},0)}),window.addAssetErr=function(e){e&&assetErrs.push(e)};
#   </script>
#   <title>
#    Machine Learning - Quora
#   </title>
#   <meta content="noindex, follow" name="robots"/>
#   <meta content="light" name="twitter:widgets:theme"/>
#   <meta content="255232486973" property="fb:pages"/>
#  </head>
#  <body class="q-platform--desktop" style="margin: 0;padding: 0;">
#   <div id="staticError" style="display: none;">
#    <div style='height: 100vh; display: flex; font-size: 15px;background-color: #fff; color: #282829;flex-direction: column; align-items: center; justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'>
#     <svg height="24px" viewbox="0 0 24 24" width="24px">
#      <g fill="none" fillrule="evenodd" id="error" stroke="none" transform="translate(3.000000, 3.000000)">
#       <path classname="icon_svg-fill_as_stroke" d="M9,12 C9.55228475,12 10,12.4477153 10,13 C10,13.5522847 9.55228475,14 9,14 C8.44771525,14 8,13.5522847 8,13 C8,12.4477153 8.44771525,12 9,12 Z" fill="#666666" fillrule="nonzero">
#       </path>
#       <path classname="icon_svg-stroke" d="M9,9.5 L9,4.5 L9,9.5 Z M9,18 C4.029,18 0,13.971 0,9 C0,4.029 4.029,0 9,0 C13.971,0 18,4.029 18,9 C18,13.971 13.971,18 9,18 Z" stroke="#666" strokelinecap="round" strokewidth="1.5">
#       </path>
#      </g>
#     </svg>
#     <p style="text-align: center; margin-top: 8px; max-width: 60vw;margin-bottom: 16px;">
#      Something went wrong. Wait a moment and try again.
#     </p>
#     <button onclick="location.reload();" style='padding: 8px 16px;font-size: 15px; background-color: #2E69FF; color: #fff;border: 0; border-radius: 9999em; appearance: none;cursor:pointer;-webkit-appearance: none;font-family:-apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'>
#      Try again
#     </button>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window.addEventListener("load",function(e){window.errorTimer=window.setTimeout(function(){var e=document.getElementById("root");if(e&&e.children&&0===e.children.length&&!window.initialRenderComplete){var t=document.getElementById("loader");t&&t.remove();var n=document.getElementById("staticError");if(n&&n.style&&n.style.display){n.style.display="block";var o=new XMLHttpRequest;o.open("POST","/ajax/log_static_error_state_shown_3RD_PARTY_POST",!0),o.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),o.setRequestHeader("Accept","*/*"),o.send("")}}},1e4)});
#   </script>
#   <div class="" id="loader" style='height: calc(100vh - 50px);margin-top: 50px;display: flex;font-size: 15px;background-color: #fff;flex-direction: column;align-items: center;justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif'>
#    <div style="position: fixed;top: 0;left: 0;right: 0;height: 50px;background-color: #fff;border-bottom: 1px solid rgb(222, 224, 225);box-shadow: 0 3px 6px rgba(0, 0, 0, 0.04)">
#    </div>
#    <style>
#     @keyframes loader-line{0%{transform:translateX(calc(-100% + 3px));opacity:.5}25%,75%{opacity:1}50%{transform:translateX(calc(100% - 3px));opacity:.5}100%{transform:translateX(calc(-100% + 3px));opacity:.5}}@keyframes entrance{0%{transform:scale(.9);opacity:0}100%{transform:scale(1);opacity:1}}@keyframes logo-entrance{100%{fill:#b92b27;opacity:1}}@keyframes logo-entrance-dark{100%{fill:#f52936;opacity:1}}#loader svg{width:48px;height:48px}#loader svg path{fill:#8e9092;opacity:.6;animation:logo-entrance .15s ease-in forwards;animation-delay:1s}#loader.loader-dark svg path{fill:#8e9092;animation-name:logo-entrance-dark}
#    </style>
#    <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#     <path class="icon_svg-fill_as_stroke" d="M20.7364 19.4633L18.9688 17.6952C20.2382 16.1439 21.0001 14.161 21.0001 12C21 7.02939 16.9705 3 12 3C7.02939 3 3 7.02939 3 12C3 16.9705 7.02948 20.9999 12 21C12.0114 21 12.0226 20.9996 12.0339 20.9996H20.0999C20.9016 20.9996 21.3032 20.0303 20.7364 19.4633ZM6.59998 12C6.59998 9.01765 9.01765 6.59998 12 6.59998C14.9823 6.59998 17.3999 9.01765 17.4 12C17.4 14.9823 14.9823 17.3999 12 17.3999C9.01765 17.4 6.59998 14.9823 6.59998 12Z" fill="#B92B27">
#     </path>
#    </svg>
#    <div style="height: 3px;width: 20px;position: relative;border-radius: 1000px;margin-top: 6px;overflow: hidden;animation: entrance .15s ease-in 1s 1 both">
#     <div style="position: absolute;top: 0px;bottom: 0px;left: 0px;width: 100%;background-color: rgba(0, 0, 0, 0.2);border-radius: 1000px;animation: loader-line 1.5s cubic-bezier(0.83, 0, 0.17, 1) 1s infinite both;transform-origin: left center;opacity: 0">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window.loaderTimer=setTimeout(function(){var e=document.getElementById("loader");e&&e.style&&e.style.display&&(e.style.display="flex")},100);
#   </script>
#   <div id="root">
#   </div>
#   <noscript>
#    Please enable Javascript and refresh the page to continue
#   </noscript>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};
# window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
# window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
# window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
# window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
# window.ansFrontendGlobals.data.inlineQueryResults.results["95ffea39c8cd3de624de2cedcd051bc9a56bc7720c8e775c9debb3a23bba70b4"] = "{\"data\":{\"viewer\":{\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"user\":null,\"showGoToFeedGrowl\":false,\"showGoToFeedGrowlBadge\":false,\"followingTabBadgeCount\":0,\"writeNavBadgeCount\":0,\"profileNavBadgeCount\":0,\"tribeNavBadgeCount\":0,\"notificationNavBadgeCount\":0,\"uid\":null,\"nid\":0,\"silosBadgeCount\":\"{}\",\"memberNetworks\":[],\"isAdminMode\":false,\"canSeeAds\":true,\"googleOneTapEnabled\":true,\"cookieBanner\":{\"id\":\"Q29va2llQmFubmVyQDA6Y1U1YVAtQlJOV0dwVVpldFhkd1prdz09\",\"__typename\":\"CookieBanner\",\"bannerType\":null,\"browserId\":\"cU5aP-BRNWGpUZetXdwZkw==\"},\"isUniversalLoggedIn\":false,\"network\":{\"canonicalSubdomain\":\"www\",\"id\":\"TmV0d29yazow\"},\"isGdprApplicable\":false,\"userNameUseJapaneseEditor\":false,\"signupId\":\"cU5aP-BRNWGpUZetXdwZkw==_1643829425003823\",\"facebookAuthNonce\":null},\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"loginShouldShowLogoutAll\":false}}";
# window.ansFrontendGlobals.data.inlineQueryResults.next["95ffea39c8cd3de624de2cedcd051bc9a56bc7720c8e775c9debb3a23bba70b4"] && window.ansFrontendGlobals.data.inlineQueryResults.next["95ffea39c8cd3de624de2cedcd051bc9a56bc7720c8e775c9debb3a23bba70b4"]();
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};
# window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
# window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
# window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
# window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
# window.ansFrontendGlobals.data.inlineQueryResults.results["d37d7a6d9eae37673abc0afdcb72e868fe797f31d59576e46254fd05706cbc80"] = "{\"data\":{\"viewer\":{\"user\":null,\"tribeWallInfo\":null,\"bannerJoinPromptNetwork\":null,\"shouldShowNonMemberJoinNetworkModal\":false,\"id\":\"Vmlld2VyQDA6MA==\"},\"network\":{\"id\":\"TmV0d29yazow\",\"__typename\":\"Network\"},\"activationWall\":null,\"actionBasedWall\":null,\"followTribeWallDeck\":null,\"browserNotifWallDeck\":null,\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"facebookPuaPixel\":{\"eventsToFire\":[\"{\\\"name\\\": \\\"PageView\\\", \\\"metadata\\\": {}, \\\"isCustom\\\": false}\",\"{\\\"name\\\": \\\"Landing\\\", \\\"metadata\\\": {}, \\\"isCustom\\\": true}\"],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"facebookPuaViewer\":{\"uid\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"googlePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"keyweePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"twitterPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaPixel\":{\"awinAwc\":null,\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaViewer\":{\"uid\":null,\"locationCountryCode\":\"US\",\"id\":\"Vmlld2VyQDA6MA==\"},\"quoraPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaViewer\":{\"primaryEmail\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"tikTokPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"liveRampPixel\":{\"liverampHash\":\"1d76d0aa8aba85b4334b14dfddd1d79c\",\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"linkedinPixel\":{\"linkedinHash\":\"934645bd35fdfca5659415660f2283d6\",\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"}}}";
# window.ansFrontendGlobals.data.inlineQueryResults.next["d37d7a6d9eae37673abc0afdcb72e868fe797f31d59576e46254fd05706cbc80"] && window.ansFrontendGlobals.data.inlineQueryResults.next["d37d7a6d9eae37673abc0afdcb72e868fe797f31d59576e46254fd05706cbc80"]();
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settings = {"action": "t", "controller": "topic", "pageType": "topic", "pageOid": 948, "getPageTypeOfRefererUrl": null, "getRefererUrl": null, "getRefererUrlTarget": null, "getParams": {}, "cookiePrefix": "m", "nid": 0, "revision": "32b16ba9653261320ac6ee76e2842f67a7311f8a", "isCanaryRevision": false, "debugToolsEnabled": false, "graphqlClientRequestLogging": true, "persistedQueriesEnabled": true, "postkey": "e5375fb2af01b208dd1702c62cb685b2", "buildNumber": 0, "broadcastId": "main-w-chan49-8888-react_clkcqfteangkltty-yco9", "broadcastDisabled": false, "tchannelData": null, "viewerUniversalUid": null, "viewerMemberUid": null, "isUniversalQuoraEmployee": false, "isMemberQuoraEmployee": false, "shouldReportE2E": false, "shouldReportReactLoadableE2E": false, "cdn": "fastly", "request_id": "2181469ee6e64b7f93ac8af587eba931", "actionTrail": null, "clientLogTrail": null, "experiments": {"test_experiment_name_2": null, "analyze_recent_metrics_holdout": null, "app_digest_bold_card": null, "react_qtext_embeds_preview_eager_loading_logged_in": null, "android_one_tap_deep_link": null, "app_download_wall_holdout": null, "android_app_inline_expand_2": null, "ios_app_inline_expand_2": null, "android_prefetch_tabs_with_get_request": null, "space_non_subscription_header_2": null, "quora_plus_comments_painted_door": null, "quora_plus_expedited_answers_painted_door": null, "programmatic_ads_i18n_feed_holdout": null, "programmatic_video_ads_logged_out": null, "programmatic_video_ads_logged_in": null, "offroad_bare_bones_feed": null, "quora_plus_cta_in_site_nav_logged_in_holdout": null, "nullspace_invite_accept_reminder_in_composers": null, "paywall_cta_text_3": null, "quora_plus_location_based_pricing": null, "paywall_blur_type": null, "feed_filter_quora_plus": null, "blurred_paywall_benefits_copy": null, "blurred_paywall_heading_copy": null, "blurred_paywall_cta_copy": null, "increase_quora_plus_monthly_pricing": null, "paywall_blur_iteration": null, "award_author_painted_door": null, "suggested_tribe_email_notif_holdout": null, "react_add_answer_email": null, "react_notifs_dropdown_menu": null, "feed_story_comment_preview_v2": null, "more_social_ui": null, "disable_app_digest_modal_on_clickthrough": null, "related_content_subfeed": null, "unified_checklist_deck": null, "image_preview_tag": null, "product_font_size": null, "digest_in_product_ui": null, "carousel_image_preview": null, "digest_in_product_ui_holdout": null, "home_feed_no_default_credential": null, "app_digest_as_feed": null, "multifeed_paging_size": null, "story_reactions": null, "in_feed_surveys_4": null, "post_expand_follow_button": null, "in_feed_surveys_holdout": null, "more_than_one_digest_per_day": null, "relevant_answer_subfeed": null, "simpler_question_story_ui": null, "space_notifs_tab": null, "evenly_distributed_feed_actionbar": null, "using_embedly_for_youtube_support": null, "video_one_click": null, "video_one_click_holdout": null, "video_auto_play_on_view": null, "prominent_create_post": null, "full_width_video_embed": null, "short_content_education": null, "post_entrypoints": null, "question_page_show_signup_wall_after_n_visits": null, "smaller_signup_wall": null, "bigger_signup_buttons": null, "bigger_signup_buttons_paid_acq": null, "show_signup_component_question_page": null}, "features": {"SmartQuotesEnabled": true, "DisabledEditorCommands": [], "QtextEmbedEagerLoadingAnswerPostPreconditions": false, "QtextEmbedEagerLoadingAnswerPost": false, "StyleLineHeightFeature": 1, "StyleFontFamilyFeature": 1, "DefaultContentBidiDirectionIsRTL": false, "AllowColorModesInInterface": false, "UseAllCapsInInterface": true, "TribeEarningsProgramFeature": true, "PaidSubscriptionEnabledForProducer": true, "ConsumerDirectSubscriptions": true, "ConsumerBundleSubscriptions": true, "ShowPaywallsToConsumers": true, "EnableSubscriptionsDebugMode": false, "EnableContentDemonetizationUpdate": true, "Is ...
#   </script>
#   <script type="text/javascript">
#    window.installSettings();
#   </script>
#   <script type="text/javascript">
#    window.ansFrontendGlobals = window.ansFrontendGlobals || {};
# window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};
# window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};
# window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};
# window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};
# window.ansFrontendGlobals.data.inlineQueryResults.results["e138e05e2c88cb102a1d14996556420c775473329fce63ffde22a1be54648caf"] = "{\"data\":{\"topic\":{\"suggestedTribeSuggestions\":[],\"id\":\"VG9waWNAMDo5NDg=\",\"__typename\":\"Topic\",\"numQuestions\":246706,\"url\":\"/topic/Machine-Learning\",\"tid\":948,\"name\":\"Machine Learning\",\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-948-100-kfdrdbxmzmijrndlcvxdftbghuzsjpmc.jpeg\",\"hasRelatedTopics\":true,\"hasLeaderboard\":true,\"relatedTopics\":[{\"id\":\"VG9waWNAMDoyMzA3\",\"__typename\":\"Topic\",\"numFollowers\":2395058,\"url\":\"/topic/Artificial-Intelligence\",\"tid\":2307,\"name\":\"Artificial Intelligence\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-2307-100-tgwpfzgzdpnbkxjhrhzjzisqgaazhuxl.jpeg\"},{\"id\":\"VG9waWNAMDo3MTU5\",\"__typename\":\"Topic\",\"numFollowers\":690253,\"url\":\"/topic/Deep-Learning\",\"tid\":7159,\"name\":\"Deep Learning\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-7159-100-vsnghaharbpvuobjoxdxslkcmdlpgrxt.jpeg\"},{\"id\":\"VG9waWNAMDo5ODA=\",\"__typename\":\"Topic\",\"numFollowers\":9577811,\"url\":\"/topic/Computer-Science\",\"tid\":980,\"name\":\"Computer Science\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-980-100-H0buhDed9OV3rFiJlV9gj5ZOHtCovmDU.jpeg\"},{\"id\":\"VG9waWNAMDo0NzE3\",\"__typename\":\"Topic\",\"numFollowers\":485612,\"url\":\"/topic/Artificial-Neural-Networks\",\"tid\":4717,\"name\":\"Artificial Neural Networks\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-4717-100-78grnIivpaUD7B2Ip7b5LAQFTJaYvqYP.jpeg\"},{\"id\":\"VG9waWNAMDo2NDY2\",\"__typename\":\"Topic\",\"numFollowers\":738675,\"url\":\"/topic/Data-Science\",\"tid\":6466,\"name\":\"Data Science\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-6466-100-kFicxKIQ4QAkRdD4Z7spmGaORM8GeLHi.jpeg\"},{\"id\":\"VG9waWNAMDo0MDc2Nw==\",\"__typename\":\"Topic\",\"numFollowers\":641363,\"url\":\"/topic/Artificial-General-Intelligence\",\"tid\":40767,\"name\":\"Artificial General Intelligence\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-40767-100-qzvptmkcfzobsenodnfcvgyullyybvro.jpeg\"},{\"id\":\"VG9waWNAMDo3Mzk0\",\"__typename\":\"Topic\",\"numFollowers\":392074,\"url\":\"/topic/Data-Mining\",\"tid\":7394,\"name\":\"Data Mining\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-7394-100-PBpn3RALoNmT4WO9LhwNOflez38an6ih.jpeg\"},{\"id\":\"VG9waWNAMDo2NDIw\",\"__typename\":\"Topic\",\"numFollowers\":272124,\"url\":\"/topic/Classification-machine-learning\",\"tid\":6420,\"name\":\"Classification (machine learning)\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-6420-100-V5jj5fEEQbS3fBlXrT7fQxL2ekua4kSV.jpeg\"},{\"id\":\"VG9waWNAMDoxMjA1\",\"__typename\":\"Topic\",\"numFollowers\":918603,\"url\":\"/topic/Statistics-academic-discipline\",\"tid\":1205,\"name\":\"Statistics (academic discipline)\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-1205-100-FylCakxe8zA7BIPIWovK8I8FgY1vF14n.jpeg\"},{\"id\":\"VG9waWNAMDozNzY2\",\"__typename\":\"Topic\",\"numFollowers\":277476,\"url\":\"/topic/Natural-Language-Processing\",\"tid\":3766,\"name\":\"Natural Language Processing\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-3766-100-wb9vPGoumIAIryG45bip5NX5q2OPOBxN.jpeg\"},{\"id\":\"VG9waWNAMDo0MjI5\",\"__typename\":\"Topic\",\"numFollowers\":576143,\"url\":\"/topic/Data-Analysis\",\"tid\":4229,\"name\":\"Data Analysis\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-4229-100-CnlapzyLmBcTVk8hC9lNX4OEnodbJeVP.jpeg\"},{\"id\":\"VG9waWNAMDoxNTEz\",\"__typename\":\"Topic\",\"numFollowers\":1765402,\"url\":\"/topic/Algorithms\",\"tid\":1513,\"name\":\"Algorithms\",\"isFollowing\":false,\"photoUrl\":\"https://qph.fs.quoracdn.net/main-thumb-t-1513- ...
# window.ansFrontendGlobals.data.inlineQueryResults.next["e138e05e2c88cb102a1d14996556420c775473329fce63ffde22a1be54648caf"] && window.ansFrontendGlobals.data.inlineQueryResults.next["e138e05e2c88cb102a1d14996556420c775473329fce63ffde22a1be54648caf"]();
#   </script>
#   <script type="text/javascript">
#    window.setTimingData({"server_time":198.387,"query_time":173.206,"head_script_time":15.936,"total_worker_time":425.778,"window_id":"react_clkcqfteangkltty","page":198.387,"request":201.605});
# window.reportPageSpeedData({"standard":{"server_side":1000,"e2e":null,"owner":30,"server_side_goal":600}});
#   </script>
#  </body>
# </html>

# %% [markdown]
# # 2. Selenium WebDriver
# - Selenium WebDriver is one of the most popular tools for **Web UI Automation**
# - It uses the WebDriver protocol to control a web browser, like Chrome, Firefox or Safari.
# - Selenium is really useful when you have to perform action on a website such as:
#   - clicking on buttons
#   - filling forms
#   - scrolling
#   - taking a screenshot
#   - execute Javascript code.
# - Installation:
#   - Install Selenium package:
#     - pip install selenium
#   - Download a webdirver based on your browser: https://www.selenium.dev/documentation/en/getting_started_with_webdriver/third_party_drivers_and_plugins/. `Be sure to download the latest version!`
#   - Place the webdrive (unzip it if the download is zipped) in a folder, e.g. a sub-folder called `drive` under the current working folder. When call selenium, point the `executable_path` parameter to that folder.
#   - mac users follow this https://stackoverflow.com/questions/43528944/python-browser-with-mac-error-chromedriver-executable-needs-to-be-in-path

# %% [markdown]
# ## 3. Use of Selenium WebDriver
#
# ### 3.1. **Navigating** (similar to beautifulsoup, but using different syntax)
#   * navigate to a link
#   * find elements by id, name, xpath, CSS selectors
#     * check this for detailed syntax: https://www.selenium.dev/documentation/webdriver/locating_elements/
#
# |    | requests/BeautifulSoup | Selenium WebDriver |
# | -- |:------------------      |:-----------|
# | Navigate to a link |   `requests.get(url)`           | `driver.get(url)`    |
# | find elements  | `soup.select()` | `driver.find_element_by_id()`<br> `driver.find_element_by_tag_name()` <br> `find_element_by_css_selector()`, <br> ...|
# | get attributes of <br>element (say `p`) | `p.attrs` <br>    `p["class"]` | `p.get_attribute("class")` |
# | get tag name | `p.name` | `p.tag_name` |

# %%
# Exercise 3.1.1 Scrape using Selenium

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions 

# for Chrome/Firefox browser, do the following
# (1) find the path where you save the webdriver 
# executable_path = 'driver/geckodriver'
# (2) initial the driver(executable_path=executable_path)
# driver=webdriver.Firefox()
# Selenium is built in in Safari
# Make sure you enable "Develop -> Allow Remote Automation"
# driver = webdriver.Safari()

driver = webdriver.Chrome()

# send a request
driver.get('https://www.quora.com/topic/Machine-Learning')

# you should see a window open

# %%
# Exercise 3.1.2. Select truncated text using Selenium

# get all questions using css selector
# find the first "more"
questions=driver.\
   find_elements_by_css_selector("span.q-box.qu-userSelect--text")
    

for i, q in enumerate(questions):
    print(i, q.text)
    print("\n")
    
# close the webdriver. 
driver.quit()
# Out:
# 0 Does being able to talk to a robot mean it thinks?
#
#
# 1 Are you worried about the possible effects of artificial intelligence?
#
#
# 2 Does being able to talk to a robot mean it thinks?
#
#
# 3 Are Asimov's 3 laws realistic to use in the development of artificial intelligence?
#
#
# 4 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 5 Are any areas of the English language still out of reach for machine translation?
#
#
# 6 What is the brutal truth about machine learning?
#
#
# 7 What language should I use for making a gui with a python backend? I would like to make it usable on both but is Java really a good option for this? My python backend will contain both backend code and machine learning stuff from sklearn so bit heavy
#
#
# 8 What could be required to control a super intelligent AI far beyond human comprehension?
#
#
# 9 How do you explain Machine Learning and Data Mining to non Computer Science people?

# %% [markdown]
# ### 3.2. Simulates users' actions performed in a web browser.
#
#   - click a button
#     * e.g. submit_button.click()
#   - fill a form
#     * e.g. text_box.send_keys("enter some text")
#   - scroll page down or up
#     * e.g. body.send_keys(Keys.PAGE_DOWN)
#   - move between windows and frames
#     * e.g. driver.switch_to_frame("frameName")
#   ...
#   - For details see https://selenium-python.readthedocs.io/navigating.html

# %%
# 3.2.1 Simulate "click"
# Click "more" link to get full answer

#driver = webdriver.Firefox(executable_path=executable_path)
#driver.get('https://www.quora.com/topic/Machine-Learning')

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

driver.implicitly_wait(10)  # set implict wait

# locate a "more" link by css selector
more_link=driver.\
find_element_by_css_selector("div.q-text.qu-cursor--pointer.qt_read_more")

# click the link element, must contain a link
more_link.click()

# Check browser to see an expanded answer

# %%
driver.quit()

# %%
# Scroll down to load more questions
import time

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

# scroll down 5 times
for i in range(5):
    driver.execute_script("window.scrollTo(0, \
    document.body.scrollHeight);")
    
    # wait for the content to be loaded
    time.sleep(2)   

questions=driver.\
   find_elements_by_css_selector("span.q-box.qu-userSelect--text")
    
for i, q in enumerate(questions):
    print(i, q.text)
    print("\n")
# Out:
# 0 Does being able to talk to a robot mean it thinks?
#
#
# 1 Are you worried about the possible effects of artificial intelligence?
#
#
# 2 Does being able to talk to a robot mean it thinks?
#
#
# 3 Are Asimov's 3 laws realistic to use in the development of artificial intelligence?
#
#
# 4 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 5 Are any areas of the English language still out of reach for machine translation?
#
#
# 6 What is the brutal truth about machine learning?
#
#
# 7 What language should I use for making a gui with a python backend? I would like to make it usable on both but is Java really a good option for this? My python backend will contain both backend code and machine learning stuff from sklearn so bit heavy
#
#
# 8 What could be required to control a super intelligent AI far beyond human comprehension?
#
#
# 9 How do you explain Machine Learning and Data Mining to non Computer Science people?
#
#
# 10 How did Andrew Ng become so good at Machine Learning?
#
#
# 11 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 12 Can I use regression to predict a market crash?
#
#
# 13 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 14 How are machine learning projects managed?
#
#
# 15 If video poker machines are not rigged, why don’t they make the code open source?
#
#
# 16 What are the dark sides of a career in AI/machine learning?
#
#
# 17 Why was GPU only invented in 1999, and how were videos and video games played before 1999, and how can it be used for things like ML, DL, and AI at the same time with running videos, graphics, or video games, doesn't this put too much pressure on it?
#
#
# 18 Is it fair to say the main technology that Tesla’s full driving technology consist of is convolutional neural nets and deep learning?
#
#
# 19 Could a genetic algorithm or AI figure out an efficient way to build the ancient Egyptian pyramids?
#
#
# 20 As a data scientist, how can I transition to be a machine learning engineer?
#
#
# 21 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 22 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 23 What is the creepiest thing any AI has done so far?
#
#
# 24 How is machine learning used in quantitative finance?
#
#
# 25 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 26 What does it mean that we don't really understand what happens in neural networks?
#
#
# 27 Why can’t robots simply be trained to defeat a CAPTCHA? How does “I’m not a robot” prevent a robot from checking the box?
#
#
# 28 In movies based on real life, do directors use AI, computer vision etc., to pick the actors who most resemble the historical characters?
#
#
# 29 What are some signs that someone is lying?
#
#
# 30 Is Andrew Ng's Machine Learning course still the best machine learning course available?
#
#
# 31 How does the AI in Tesla distinguish between a large hole in the road or a dark stain on the road?
#
#
# 32 I have caught a serious bug of learning Machine Learning. And I want to participate in kaggle competitions. I am thinking of leaving my current job for this process. What is your advice on this?
#
#
# 33 Why do Google and Facebook give away their deep learning frameworks (TensorFlow and PyTorch) for free?
#
#
# 34 Why can't programmers figure out the source code or basic algorithm of a program based on the machine code?
#
#
# 35 Why is C# so behind of Python in Artificial Intelligence and Machine Learning? Why is Microsoft not doing more for .NET future in AI?
#
#
# 36 What is the most mathematically involved machine learning algorithm?
#
#
# 37 How can I become a data scientist?
#
#
# 38 How well do machine learning researchers need to code?
#
#
# 39 What could be required to control a super intelligent AI far beyond human comprehension?
#
#
# 40 What is an advanced machine learning engineer able to do that a mediocre one can’t?
#
#
# 41 Why is artificial intelligence a hype?
#
#
# 42 What skills are needed for machine learning jobs?
#
#
# 43 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 44 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 45 Why does University of Montreal not have a higher profile in tech, given Yoshua Bengio is one of the foremost experts in deep learning?
#
#
# 46 What are the disadvantages of Julia compared to Python?
#
#
# 47 What are the dark sides of a career in AI/machine learning?
#
#
# 48 Is backpropagation the most important development in machine learning?
#
#
# 49 Is it true that it will be more difficult to become a machine learning engineer as there are more and more blackbox machine learning libraries, like TensorFlow and PyTorch, and employers are looking for people who understand the maths?
#
#
# 50 How do I learn machine learning?
#
#
# 51 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 52 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 53 What laptop do I buy for deep learning?
#
#
# 54 Why is deep learning so easy?
#
#
# 55 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 56 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 57 Why is Machine Learning Maths heavy?
#
#
# 58 What are the biggest signs that someone has narcissistic personality disorder?
#
#
# 59 Why are Scikit-learn machine learning models not as widely used in industry as TensorFlow or PyTorch?
#
#
# 60 Is it good to attend the IIIT Hyderabad's artificial intelligence and machine learning certification program? The course duration is 15 months and the cost is 1.5 to 2 lakhs.
#
#
# 61 Why don't you call it "machine learning" and not "artificial intelligence"?
#
#
# 62 Why don't we understand how neural networks work?
#
#
# 63 Is stochastic math and Brownian motion still important to quantitative hedge funds? Is it all about AI and machine learning now?
#
#
# 64 What are the dark sides of a career in AI/machine learning?
#
#
# 65 Which is better: Python or C++?
#
#
# 66 Can linear regression work on non-linear data sets?
#
#
# 67 What can humans do better than machine learning AI?
#
#
# 68 Is knowing Python well enough to be a software engineer in machine learning?
#
#
# 69 What are my chances for getting into a top CS PhD program (Like Harvard, Columbia, NYU, etc.) with a MS in CS, 2 accepted IEEE conf. papers, 2 years of research exp. in deep learning on neuroscience datasets, 162 quant 154 verbal GRE, and a 3.7 GPA?

# %%
driver.quit()

# %% [markdown]
# ### 3.3. Wait
#   - Because of the use of AJAX technologies, web elements often load at different time intervals.
#   - This makes locating elements difficult.
#     - if an element is not loaded,  a locating function will raise an ElementNotVisibleException exception.
#   - Two types of waits
#     - `implicit`: When a Webdriver locates for any element, but the element is not available, instead of throwing "No Such Element Exception" immediately, the Webdriver waits for a certain amount of time. By the time it is still not available, then the error is thrown.
#       * Implicit wait is set at the driver level and applies to <font color='blue'>any locating function</font>
#     - `explicit`: WebDriver waits for a certain condition to occur before proceeding further with execution
#       * Explicit wait is set at <font color='blue'>each locating function</font>
#     - check out https://www.selenium.dev/documentation/webdriver/waits/

# %% [markdown]
# Assume you're looking for a question, but you're not sure if this question has been loaded into the page
# - Case 1: If this question is not in the page, you get an error immediately
# - Case 2: If it takes time to load the question, use implict wait to wait for some time
# - Case 3: You can keep scroll down until the question has been loaded or max tries reached
#     - Use `try ... else` block to handle the exception more elegently

# %%
# If the element is not there, you'll see an error immediately

#driver = webdriver.Safari()
driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

q = driver.find_element_by_css_selector('a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]')

print(q.text)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-31-c1ca0fd6981e> in <module>
#       5 driver.get('https://www.quora.com/topic/Machine-Learning')
#       6
# ----> 7 q = driver.find_element_by_css_selector('a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]')
#       8
#       9 print(q.text)
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]"}
#   (Session info: chrome=97.0.4692.99)

# %%
driver.quit()

# %%
# If the element is not there, you'll see an error after the waiting

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

driver.implicitly_wait(10)

q = driver.find_element_by_css_selector('a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]')
print(q.text)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-32-c185ce9fa9b8> in <module>
#       6 driver.implicitly_wait(10)
#       7
# ----> 8 q = driver.find_element_by_css_selector('a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]')
#       9 print(q.text)
#      10 driver.quit()
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]"}
#   (Session info: chrome=97.0.4692.99)

# %%
driver.quit()

# %%
# If the element is not there, 
# you keep scrolling down until the element is there
# or scrolling for max number of times
# try except can catch the error
# https://selenium-python.readthedocs.io/waits.html#explicit-waits

driver = webdriver.Chrome()
driver.get('https://www.quora.com/topic/Machine-Learning')

found = False
max_try = 10  # max number of scroll-downs
cnt = 0

while not found and cnt < max_try:
    
    try:
        # This waits up to 5 seconds before throwing a TimeoutException 
        # unless it finds the element to return 
        
        q = WebDriverWait(driver,5).until(\
                    expected_conditions.\
                    presence_of_element_located((By.CSS_SELECTOR, \
                    # An expectation for checking that an element is present on the DOM of a page.
                   'a[href="https://www.quora.com/How-can-I-become-a-data-scientist-1"]')))
        
        found = True
        print(q.text)

    except:     # item not there yet
        
        driver.execute_script("window.scrollTo(0, \
        document.body.scrollHeight);")
     
        cnt += 1
        
driver.quit()
# Out:
# How can I become a data scientist?
